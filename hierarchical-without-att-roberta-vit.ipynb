# %%
#Setup Gdrive file download extention 
# !conda install -y gdown
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     filelock-3.15.4            |     pyhd8ed1ab_0          17 KB  conda-forge
#     gdown-5.2.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_1         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.15.4-pyhd8ed1ab_0
#   gdown              conda-forge/noarch::gdown-5.2.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2024.6.2-hbcca054_0 --> 2024.7.4-hbcca054_0
#   certifi                             2024.2.2-pyhd8ed1ab_0 --> 2024.7.4-pyhd8ed1ab_0
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4ab18f5_1
#
#
#
# Downloading and Extracting Packages:
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
# certifi-2024.7.4     | 156 KB    |                                       |   0%
#
# ca-certificates-2024 | 151 KB    |                                       |   0%
#
#
# gdown-5.2.0          | 21 KB     |                                       |   0%
#
#
#
# openssl-3.3.1        | 2.8 MB    | ####1                                 |  11%
# certifi-2024.7.4     | 156 KB    | ###8                                  |  10%
#
# ca-certificates-2024 | 151 KB    | ###############6                      |  42%
#
#
# gdown-5.2.0          | 21 KB     | ###########################7          |  75%
#
#
#
# filelock-3.15.4      | 17 KB     | ##################################### | 100%
#
#
#
# filelock-3.15.4      | 17 KB     | ##################################### | 100%
#
# ca-certificates-2024 | 151 KB    | ##################################### | 100%
#
#
# gdown-5.2.0          | 21 KB     | ##################################### | 100%
# certifi-2024.7.4     | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !gdown --id <File ID>
# !gdown --id 1SdJEoAna8Z4bJ3_dJ23D4ldYlaxyWRor
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1SdJEoAna8Z4bJ3_dJ23D4ldYlaxyWRor
# From (redirected): https://drive.google.com/uc?id=1SdJEoAna8Z4bJ3_dJ23D4ldYlaxyWRor&confirm=t&uuid=5aca33e8-cb02-4b07-976a-702ac84f7a07
# To: /kaggle/working/all Photos.zip
# 100%|███████████████████████████████████████| 1.81G/1.81G [00:08<00:00, 210MB/s]

# %%
# !unzip 'all Photos.zip'
# Out:
# Archive:  all Photos.zip
#   inflating: all Photos/1.jpg
#   inflating: all Photos/10.jpg
#   inflating: all Photos/100.jpg
#   inflating: all Photos/1000.jpg
#   inflating: all Photos/1001.jpg
#   inflating: all Photos/1002.jpg
#   inflating: all Photos/1003.jpg
#   inflating: all Photos/1004.jpg
#   inflating: all Photos/1005.jpg
#   inflating: all Photos/1006.jpg
#   inflating: all Photos/1007.jpg
#   inflating: all Photos/1008.jpg
#   inflating: all Photos/1009.jpg
#   inflating: all Photos/101.jpg
#   inflating: all Photos/1010.jpg
#   inflating: all Photos/1011.jpg
#   inflating: all Photos/1012.jpg
#   inflating: all Photos/1013.jpg
#   inflating: all Photos/1014.jpg
#   inflating: all Photos/1015.jpg
#   inflating: all Photos/1016.jpg
#   inflating: all Photos/1017.jpg
#   inflating: all Photos/1018.jpg
#   inflating: all Photos/1019.jpg
#   inflating: all Photos/102.jpg
#   inflating: all Photos/1020.jpg
#   inflating: all Photos/1021.jpg
#   inflating: all Photos/1022.jpg
#   inflating: all Photos/1023.jpg
#   inflating: all Photos/1024.jpg
#   inflating: all Photos/1025.jpg
#   inflating: all Photos/1026.jpg
#   inflating: all Photos/1027.jpg
#   inflating: all Photos/1028.jpg
#   inflating: all Photos/1029.jpg
#   inflating: all Photos/103.jpg
#   inflating: all Photos/1030.jpg
#   inflating: all Photos/1031.jpg
#   inflating: all Photos/1032.jpg
#   inflating: all Photos/1033.jpg
#   inflating: all Photos/1034.jpg
#   inflating: all Photos/1035.jpg
#   inflating: all Photos/1036.jpg
#   inflating: all Photos/1037.jpg
#   inflating: all Photos/1038.jpg
#   inflating: all Photos/1039.jpg
#   inflating: all Photos/104.jpg
#   inflating: all Photos/1040.jpg
#   inflating: all Photos/1041.jpg
#   inflating: all Photos/1042.jpg
#   inflating: all Photos/1043.jpg
#   inflating: all Photos/1044.jpg
#   inflating: all Photos/1045.jpg
#   inflating: all Photos/1046.jpg
#   inflating: all Photos/1047.jpg
#   inflating: all Photos/1048.jpg
#   inflating: all Photos/1049.jpg
#   inflating: all Photos/105.jpg
#   inflating: all Photos/1050.jpg
#   inflating: all Photos/1051.jpg
#   inflating: all Photos/1052.jpg
#   inflating: all Photos/1053.jpg
#   inflating: all Photos/1054.jpg
#   inflating: all Photos/1055.jpg
#   inflating: all Photos/1056.jpg
#   inflating: all Photos/1057.jpg
#   inflating: all Photos/1058.jpg
#   inflating: all Photos/1059.jpg
#   inflating: all Photos/106.jpg
#   inflating: all Photos/1060.jpg
#   inflating: all Photos/1061.jpg
#   inflating: all Photos/1062.jpg
#   inflating: all Photos/1063.jpg
#   inflating: all Photos/1064.jpg
#   inflating: all Photos/1065.jpg
#   inflating: all Photos/1066.jpg
#   inflating: all Photos/1067.jpg
#   inflating: all Photos/1068.jpg
#   inflating: all Photos/1069.jpg
#   inflating: all Photos/107.jpg
#   inflating: all Photos/1070.jpg
#   inflating: all Photos/1071.jpg
#   inflating: all Photos/1072.jpg
#   inflating: all Photos/1073.jpg
#   inflating: all Photos/1074.jpg
#   inflating: all Photos/1075.jpg
#   inflating: all Photos/1076.jpg
#   inflating: all Photos/1077.jpg
#   inflating: all Photos/1078.jpg
#   inflating: all Photos/1079.jpg
#   inflating: all Photos/108.jpg
#   inflating: all Photos/1080.jpg
#   inflating: all Photos/1081.jpg
#   inflating: all Photos/1082.jpg
#   inflating: all Photos/1083.jpg
#   inflating: all Photos/1084.jpg
#   inflating: all Photos/1085.jpg
#   inflating: all Photos/1086.jpg
#   inflating: all Photos/1087.jpg
#   inflating: all Photos/1088.jpg
#   inflating: all Photos/1089.jpg
#   inflating: all Photos/109.jpg
#   inflating: all Photos/1090.jpg
#   inflating: all Photos/1091.jpg
#   inflating: all Photos/1092.jpg
#   inflating: all Photos/1093.jpg
#   inflating: all Photos/1094.jpg
#   inflating: all Photos/1095.jpg
#   inflating: all Photos/1096.jpg
#   inflating: all Photos/1097.jpg
#   inflating: all Photos/1098.jpg
#   inflating: all Photos/1099.jpg
#   inflating: all Photos/11.jpg
#   inflating: all Photos/110.jpg
#   inflating: all Photos/1100.jpg
#   inflating: all Photos/1101.jpg
#   inflating: all Photos/1102.jpg
#   inflating: all Photos/1103.jpg
#   inflating: all Photos/1104.jpg
#   inflating: all Photos/1105.jpg
#   inflating: all Photos/1106.jpg
#   inflating: all Photos/1107.jpg
#   inflating: all Photos/1108.jpg
#   inflating: all Photos/1109.jpg
#   inflating: all Photos/111.jpg
#   inflating: all Photos/1110.jpg
#   inflating: all Photos/1111.jpg
#   inflating: all Photos/1112.jpg
#   inflating: all Photos/1113.jpg
#   inflating: all Photos/1114.jpg
#   inflating: all Photos/1115.jpg
#   inflating: all Photos/1116.jpg
#   inflating: all Photos/1117.jpg
#   inflating: all Photos/1118.jpg
#   inflating: all Photos/1119.jpg
#   inflating: all Photos/112.jpg
#   inflating: all Photos/1120.jpg
#   inflating: all Photos/1121.jpg
#   inflating: all Photos/1122.jpg
#   inflating: all Photos/1123.jpg
#   inflating: all Photos/1124.jpg
#   inflating: all Photos/1125.jpg
#   inflating: all Photos/1126.jpg
#   inflating: all Photos/1127.jpg
#   inflating: all Photos/1128.jpg
#   inflating: all Photos/1129.jpg
#   inflating: all Photos/113.jpg
#   inflating: all Photos/1130.jpg
#   inflating: all Photos/1131.jpg
#   inflating: all Photos/1132.jpg
#   inflating: all Photos/1133.jpg
#   inflating: all Photos/1134.jpg
#   inflating: all Photos/1135.jpg
#   inflating: all Photos/1136.jpg
#   inflating: all Photos/1137.jpg
#   inflating: all Photos/1138.jpg
#   inflating: all Photos/1139.jpg
#   inflating: all Photos/114.jpg
#   inflating: all Photos/1140.jpg
#   inflating: all Photos/1141.jpg
#   inflating: all Photos/1142.jpg
#   inflating: all Photos/1143.jpg
#   inflating: all Photos/1144.jpg
#   inflating: all Photos/1145.jpg
#   inflating: all Photos/1146.jpg
#   inflating: all Photos/1147.jpg
#   inflating: all Photos/1148.jpg
#   inflating: all Photos/1149.jpg
#   inflating: all Photos/115.jpg
#   inflating: all Photos/1150.jpg
#   inflating: all Photos/1151.jpg
#   inflating: all Photos/1152.jpg
#   inflating: all Photos/1153.jpg
#   inflating: all Photos/1154.jpg
#   inflating: all Photos/1155.jpg
#   inflating: all Photos/1156.jpg
#   inflating: all Photos/1157.jpg
#   inflating: all Photos/1158.jpg
#   inflating: all Photos/1159.jpg
#   inflating: all Photos/116.png
#   inflating: all Photos/1160.jpg
#   inflating: all Photos/1161.jpg
#   inflating: all Photos/1162.jpg
#   inflating: all Photos/1163.jpg
#   inflating: all Photos/1164.jpg
#   inflating: all Photos/1165.jpg
#   inflating: all Photos/1166.jpg
#   inflating: all Photos/1167.jpg
#   inflating: all Photos/1168.jpg
#   inflating: all Photos/1169.jpg
#   inflating: all Photos/117.png
#   inflating: all Photos/1170.jpg
#   inflating: all Photos/1171.jpg
#   inflating: all Photos/1172.jpg
#   inflating: all Photos/1173.jpg
#   inflating: all Photos/1174.jpg
#   inflating: all Photos/1175.jpg
#   inflating: all Photos/1176.jpg
#   inflating: all Photos/1177.jpg
#   inflating: all Photos/1178.jpg
#   inflating: all Photos/1179.jpg
#   inflating: all Photos/118.jpg
#   inflating: all Photos/1180.jpg
#   inflating: all Photos/1181.jpg
#   inflating: all Photos/1182.jpg
#   inflating: all Photos/1183.jpg
#   inflating: all Photos/1184.jpg
#   inflating: all Photos/1185.jpg
#   inflating: all Photos/1186.jpg
#   inflating: all Photos/1187.jpg
#   inflating: all Photos/1188.jpg
#   inflating: all Photos/1189.jpg
#   inflating: all Photos/119.jpg
#   inflating: all Photos/1190.jpg
#   inflating: all Photos/1191.jpg
#   inflating: all Photos/1192.jpg
#   inflating: all Photos/1193.jpg
#   inflating: all Photos/1194.jpg
#   inflating: all Photos/1195.jpg
#   inflating: all Photos/1196.jpg
#   inflating: all Photos/1197.jpg
#   inflating: all Photos/1198.jpg
#   inflating: all Photos/1199.jpg
#   inflating: all Photos/12.jpg
#   inflating: all Photos/120.jpg
#   inflating: all Photos/1200.jpg
#   inflating: all Photos/1201.jpg
#   inflating: all Photos/1202.jpg
#   inflating: all Photos/1203.jpg
#   inflating: all Photos/1204.jpg
#   inflating: all Photos/1205.jpg
#   inflating: all Photos/1206.jpg
#   inflating: all Photos/1207.jpg
#   inflating: all Photos/1208.jpg
#   inflating: all Photos/1209.jpg
#   inflating: all Photos/121.jpg
#   inflating: all Photos/1210.jpg
#   inflating: all Photos/1211.jpg
#   inflating: all Photos/1212.jpg
#   inflating: all Photos/1213.jpg
#   inflating: all Photos/1214.jpg
#   inflating: all Photos/1215.jpg
#   inflating: all Photos/1216.jpg
#   inflating: all Photos/1217.jpg
#   inflating: all Photos/1218.jpg
#   inflating: all Photos/1219.jpg
#   inflating: all Photos/122.jpg
#   inflating: all Photos/1220.jpg
#   inflating: all Photos/1221.jpg
#   inflating: all Photos/1222.jpg
#   inflating: all Photos/1223.jpg
#   inflating: all Photos/1224.jpg
#   inflating: all Photos/1225.jpg
#   inflating: all Photos/1226.jpg
#   inflating: all Photos/1227.jpg
#   inflating: all Photos/1228.jpg
#   inflating: all Photos/1229.jpg
#   inflating: all Photos/123.jpg
#   inflating: all Photos/1230.jpg
#   inflating: all Photos/1231.jpg
#   inflating: all Photos/1232.jpg
#   inflating: all Photos/1233.jpg
#   inflating: all Photos/1234.jpg
#   inflating: all Photos/1235.jpg
#   inflating: all Photos/1236.jpg
#   inflating: all Photos/1237.jpg
#   inflating: all Photos/1238.jpg
#   inflating: all Photos/1239.jpg
#   inflating: all Photos/124.jpg
#   inflating: all Photos/1240.jpg
#   inflating: all Photos/1241.jpg
#   inflating: all Photos/1242.jpg
#   inflating: all Photos/1243.jpg
#   inflating: all Photos/1244.jpg
#   inflating: all Photos/1245.jpg
#   inflating: all Photos/1246.jpg
#   inflating: all Photos/1247.jpg
#   inflating: all Photos/1248.jpg
#   inflating: all Photos/1249.jpg
#   inflating: all Photos/125.jpg
#   inflating: all Photos/1250.jpg
#   inflating: all Photos/1251.jpg
#   inflating: all Photos/1252.jpg
#   inflating: all Photos/1253.jpg
#   inflating: all Photos/1254.jpg
#   inflating: all Photos/1255.jpg
#   inflating: all Photos/1256.jpg
#   inflating: all Photos/1257.jpg
#   inflating: all Photos/1258.jpg
#   inflating: all Photos/1259.jpg
#   inflating: all Photos/126.jpg
#   inflating: all Photos/1260.jpg
#   inflating: all Photos/1261.jpg
#   inflating: all Photos/1262.jpg
#   inflating: all Photos/1263.jpg
#   inflating: all Photos/1264.jpg
#   inflating: all Photos/1265.jpg
#   inflating: all Photos/1266.jpg
#   inflating: all Photos/1267.jpg
#   inflating: all Photos/1268.jpg
#   inflating: all Photos/1269.jpg
#   inflating: all Photos/127.png
#   inflating: all Photos/1270.jpg
#   inflating: all Photos/1271.jpg
#   inflating: all Photos/1272.jpg
#   inflating: all Photos/1273.jpg
#   inflating: all Photos/1274.jpg
#   inflating: all Photos/1275.jpg
#   inflating: all Photos/1276.jpg
#   inflating: all Photos/1277.jpg
#   inflating: all Photos/1278.jpg
#   inflating: all Photos/1279.jpg
#   inflating: all Photos/128.png
#   inflating: all Photos/1280.jpg
#   inflating: all Photos/1281.jpg
#   inflating: all Photos/1282.jpg
#   inflating: all Photos/1283.jpg
#   inflating: all Photos/1284.jpg
#   inflating: all Photos/1285.jpg
#   inflating: all Photos/1286.jpg
#   inflating: all Photos/1287.jpg
#   inflating: all Photos/1288.jpg
#   inflating: all Photos/1289.jpg
#   inflating: all Photos/129.png
#   inflating: all Photos/1290.jpg
#   inflating: all Photos/1291.jpg
#   inflating: all Photos/1292.jpg
#   inflating: all Photos/1293.jpg
#   inflating: all Photos/1294.jpg
#   inflating: all Photos/1295.jpg
#   inflating: all Photos/1296.jpg
#   inflating: all Photos/1297.jpg
#   inflating: all Photos/1298.jpg
#   inflating: all Photos/1299.jpg
#   inflating: all Photos/13.jpg
#   inflating: all Photos/130.jpg
#   inflating: all Photos/1300.jpg
#   inflating: all Photos/1301.jpg
#   inflating: all Photos/1302.jpg
#   inflating: all Photos/1303.jpg
#   inflating: all Photos/1304.jpg
#   inflating: all Photos/1305.jpg
#   inflating: all Photos/1306.jpg
#   inflating: all Photos/1307.jpg
#   inflating: all Photos/1308.jpg
#   inflating: all Photos/1309.jpg
#   inflating: all Photos/131.jpg
#   inflating: all Photos/1310.jpg
#   inflating: all Photos/1311.jpg
#   inflating: all Photos/1312.jpg
#   inflating: all Photos/1313.jpg
#   inflating: all Photos/1314.jpg
#   inflating: all Photos/1315.jpg
#   inflating: all Photos/1316.jpg
#   inflating: all Photos/1317.jpg
#   inflating: all Photos/1318.jpg
#   inflating: all Photos/1319.jpg
#   inflating: all Photos/132.jpg
#   inflating: all Photos/1320.jpg
#   inflating: all Photos/1321.jpg
#   inflating: all Photos/1322.jpg
#   inflating: all Photos/1323.jpg
#   inflating: all Photos/1324.jpg
#   inflating: all Photos/1325.jpg
#   inflating: all Photos/1326.jpg
#   inflating: all Photos/1327.jpg
#   inflating: all Photos/1328.jpg
#   inflating: all Photos/1329.jpg
#   inflating: all Photos/133.jpg
#   inflating: all Photos/1330.jpg
#   inflating: all Photos/1331.jpg
#   inflating: all Photos/1332.jpg
#   inflating: all Photos/1333.jpg
#   inflating: all Photos/1334.jpg
#   inflating: all Photos/1335.jpg
#   inflating: all Photos/1336.jpg
#   inflating: all Photos/1337.jpg
#   inflating: all Photos/1338.jpg
#   inflating: all Photos/1339.jpg
#   inflating: all Photos/134.jpg
#   inflating: all Photos/1340.jpg
#   inflating: all Photos/1341.jpg
#   inflating: all Photos/1342.jpg
#   inflating: all Photos/1343.jpg
#   inflating: all Photos/1344.jpg
#   inflating: all Photos/1345.jpg
#   inflating: all Photos/1346.jpg
#   inflating: all Photos/1347.jpg
#   inflating: all Photos/1348.jpg
#   inflating: all Photos/1349.jpg
#   inflating: all Photos/135.jpg
#   inflating: all Photos/1350.jpg
#   inflating: all Photos/1351.jpg
#   inflating: all Photos/1352.jpg
#   inflating: all Photos/1353.jpg
#   inflating: all Photos/1354.jpg
#   inflating: all Photos/1355.jpg
#   inflating: all Photos/1356.jpg
#   inflating: all Photos/1357.jpg
#   inflating: all Photos/1358.jpg
#   inflating: all Photos/1359.jpg
#   inflating: all Photos/136.jpg
#   inflating: all Photos/1360.jpg
#   inflating: all Photos/1361.jpg
#   inflating: all Photos/1362.jpg
#   inflating: all Photos/1363.jpg
#   inflating: all Photos/1364.jpg
#   inflating: all Photos/1365.jpg
#   inflating: all Photos/1366.jpg
#   inflating: all Photos/1367.jpg
#   inflating: all Photos/1368.jpg
#   inflating: all Photos/1369.jpg
#   inflating: all Photos/137.jpg
#   inflating: all Photos/1370.jpg
#   inflating: all Photos/1371.jpg
#   inflating: all Photos/1372.jpg
#   inflating: all Photos/1373.jpg
#   inflating: all Photos/1374.jpg
#   inflating: all Photos/1375.jpg
#   inflating: all Photos/1376.jpg
#   inflating: all Photos/1377.jpg
#   inflating: all Photos/1378.jpg
#   inflating: all Photos/1379.jpg
#   inflating: all Photos/138.jpg
#   inflating: all Photos/1380.jpg
#   inflating: all Photos/1381.jpg
#   inflating: all Photos/1382.jpg
#   inflating: all Photos/1383.jpg
#   inflating: all Photos/1384.jpg
#   inflating: all Photos/1385.jpg
#   inflating: all Photos/1386.jpg
#   inflating: all Photos/1387.jpg
#   inflating: all Photos/1388.jpg
#   inflating: all Photos/1389.jpg
#   inflating: all Photos/139.jpg
#   inflating: all Photos/1390.jpg
#   inflating: all Photos/1391.jpg
#   inflating: all Photos/1392.jpg
#   inflating: all Photos/1393.jpg
#   inflating: all Photos/1394.jpg
#   inflating: all Photos/1395.jpg
#   inflating: all Photos/1396.jpg
#   inflating: all Photos/1397.jpg
#   inflating: all Photos/1398.jpg
#   inflating: all Photos/1399.jpg
#   inflating: all Photos/14.jpg
#   inflating: all Photos/140.jpg
#   inflating: all Photos/1400.jpg
#   inflating: all Photos/1401.jpg
#   inflating: all Photos/1402.jpg
#   inflating: all Photos/1403.jpg
#   inflating: all Photos/1404.jpg
#   inflating: all Photos/1405.jpg
#   inflating: all Photos/1406.jpg
#   inflating: all Photos/1407.jpg
#   inflating: all Photos/1408.jpg
#   inflating: all Photos/1409.jpg
#   inflating: all Photos/141.jpg
#   inflating: all Photos/1410.jpg
#   inflating: all Photos/1411.jpg
#   inflating: all Photos/1412.jpg
#   inflating: all Photos/1413.jpg
#   inflating: all Photos/1414.jpg
#   inflating: all Photos/1415.jpg
#   inflating: all Photos/1416.jpg
#   inflating: all Photos/1417.jpg
#   inflating: all Photos/1418.jpg
#   inflating: all Photos/1419.jpg
#   inflating: all Photos/142.jpg
#   inflating: all Photos/1420.jpg
#   inflating: all Photos/1421.jpg
#   inflating: all Photos/1422.jpg
#   inflating: all Photos/1423.jpg
#   inflating: all Photos/1424.jpg
#   inflating: all Photos/1425.jpg
#   inflating: all Photos/1426.jpg
#   inflating: all Photos/1427.jpg
#   inflating: all Photos/1428.jpg
#   inflating: all Photos/1429.jpg
#   inflating: all Photos/143.jpg
#   inflating: all Photos/1430.jpg
#   inflating: all Photos/1431.jpg
#   inflating: all Photos/1432.jpg
#   inflating: all Photos/1433.jpg
#   inflating: all Photos/1434.jpg
#   inflating: all Photos/1435.jpg
#   inflating: all Photos/1436.jpg
#   inflating: all Photos/1437.jpg
#   inflating: all Photos/1438.jpg
#   inflating: all Photos/1439.jpg
#   inflating: all Photos/144.jpg
#   inflating: all Photos/1440.jpg
#   inflating: all Photos/1441.jpg
#   inflating: all Photos/1442.jpg
#   inflating: all Photos/1443.jpg
#   inflating: all Photos/1444.jpg
#   inflating: all Photos/1445.jpg
#   inflating: all Photos/1446.jpg
#   inflating: all Photos/1447.jpg
#   inflating: all Photos/1448.jpg
#   inflating: all Photos/1449.jpg
#   inflating: all Photos/145.jpg
#   inflating: all Photos/1450.jpg
#   inflating: all Photos/1451.jpg
#   inflating: all Photos/1452.jpg
#   inflating: all Photos/1453.jpg
#   inflating: all Photos/1454.jpg
#   inflating: all Photos/1455.jpg
#   inflating: all Photos/1456.jpg
#   inflating: all Photos/1457.jpg
#   inflating: all Photos/1458.jpg
#   inflating: all Photos/1459.jpg
#   inflating: all Photos/146.jpg
#   inflating: all Photos/1460.jpg
#   inflating: all Photos/1461.jpg
#   inflating: all Photos/1462.jpg
#   inflating: all Photos/1463.jpg
#   inflating: all Photos/1464.jpg
#   inflating: all Photos/1465.jpg
#   inflating: all Photos/1466.jpg
#   inflating: all Photos/1467.jpg
#   inflating: all Photos/1468.jpg
#   inflating: all Photos/1469.jpg
#   inflating: all Photos/147.jpg
#   inflating: all Photos/1470.jpg
#   inflating: all Photos/1471.jpg
#   inflating: all Photos/1472.jpg
#   inflating: all Photos/1473.jpg
#   inflating: all Photos/1474.jpg
#   inflating: all Photos/1475.jpg
#   inflating: all Photos/1476.jpg
#   inflating: all Photos/1477.jpg
#   inflating: all Photos/1478.jpg
#   inflating: all Photos/1479.jpg
#   inflating: all Photos/148.jpg
#   inflating: all Photos/1480.jpg
#   inflating: all Photos/1481.jpg
#   inflating: all Photos/1482.jpg
#   inflating: all Photos/1483.jpg
#   inflating: all Photos/1484.jpg
#   inflating: all Photos/1485.jpg
#   inflating: all Photos/1486.jpg
#   inflating: all Photos/1487.jpg
#   inflating: all Photos/1488.jpg
#   inflating: all Photos/1489.jpg
#   inflating: all Photos/149.jpg
#   inflating: all Photos/1490.jpg
#   inflating: all Photos/1491.jpg
#   inflating: all Photos/1492.jpg
#   inflating: all Photos/1493.jpg
#   inflating: all Photos/1494.jpg
#   inflating: all Photos/1495.jpg
#   inflating: all Photos/1496.jpg
#   inflating: all Photos/1497.jpg
#   inflating: all Photos/1498.jpg
#   inflating: all Photos/1499.jpg
#   inflating: all Photos/15.png
#   inflating: all Photos/150.jpg
#   inflating: all Photos/1500.jpg
#   inflating: all Photos/1501.jpg
#   inflating: all Photos/1502.jpg
#   inflating: all Photos/1503.jpg
#   inflating: all Photos/1504.jpg
#   inflating: all Photos/1505.jpg
#   inflating: all Photos/1506.jpg
#   inflating: all Photos/1507.jpg
#   inflating: all Photos/1508.jpg
#   inflating: all Photos/1509.jpg
#   inflating: all Photos/151.jpg
#   inflating: all Photos/1510.jpg
#   inflating: all Photos/1511.jpg
#   inflating: all Photos/1512.jpg
#   inflating: all Photos/1513.jpg
#   inflating: all Photos/1514.jpg
#   inflating: all Photos/1515.jpg
#   inflating: all Photos/1516.jpg
#   inflating: all Photos/1517.jpg
#   inflating: all Photos/1518.jpg
#   inflating: all Photos/1519.jpg
#   inflating: all Photos/152.jpg
#   inflating: all Photos/1520.jpg
#   inflating: all Photos/1521.jpg
#   inflating: all Photos/1522.jpg
#   inflating: all Photos/1523.jpg
#   inflating: all Photos/1524.jpg
#   inflating: all Photos/1525.jpg
#   inflating: all Photos/1526.jpg
#   inflating: all Photos/1527.jpg
#   inflating: all Photos/1528.jpg
#   inflating: all Photos/1529.jpg
#   inflating: all Photos/153.jpg
#   inflating: all Photos/1530.jpg
#   inflating: all Photos/1531.jpg
#   inflating: all Photos/1532.jpg
#   inflating: all Photos/1533.jpg
#   inflating: all Photos/1534.jpg
#   inflating: all Photos/1535.jpg
#   inflating: all Photos/1536.jpg
#   inflating: all Photos/1537.jpg
#   inflating: all Photos/1538.jpg
#   inflating: all Photos/1539.jpg
#   inflating: all Photos/154.jpg
#   inflating: all Photos/1540.jpg
#   inflating: all Photos/1541.jpg
#   inflating: all Photos/1542.jpg
#   inflating: all Photos/1543.jpg
#   inflating: all Photos/1544.jpg
#   inflating: all Photos/1545.jpg
#   inflating: all Photos/1546.jpg
#   inflating: all Photos/1547.jpg
#   inflating: all Photos/1548.jpg
#   inflating: all Photos/1549.jpg
#   inflating: all Photos/155.jpg
#   inflating: all Photos/1550.jpg
#   inflating: all Photos/1551.jpg
#   inflating: all Photos/1552.jpg
#   inflating: all Photos/1553.jpg
#   inflating: all Photos/1554.jpg
#   inflating: all Photos/1555.jpg
#   inflating: all Photos/1556.jpg
#   inflating: all Photos/1557.jpg
#   inflating: all Photos/1558.jpg
#   inflating: all Photos/1559.jpg
#   inflating: all Photos/156.jpg
#   inflating: all Photos/1560.jpg
#   inflating: all Photos/1561.jpg
#   inflating: all Photos/1562.jpg
#   inflating: all Photos/1563.jpg
#   inflating: all Photos/1564.jpg
#   inflating: all Photos/1565.jpg
#   inflating: all Photos/1566.jpg
#   inflating: all Photos/1567.jpg
#   inflating: all Photos/1568.jpg
#   inflating: all Photos/1569.jpg
#   inflating: all Photos/157.jpg
#   inflating: all Photos/1570.jpg
#   inflating: all Photos/1571.jpg
#   inflating: all Photos/1572.jpg
#   inflating: all Photos/1573.jpg
#   inflating: all Photos/1574.jpg
#   inflating: all Photos/1575.jpg
#   inflating: all Photos/1576.jpg
#   inflating: all Photos/1577.jpg
#   inflating: all Photos/1578.jpg
#   inflating: all Photos/1579.jpg
#   inflating: all Photos/158.jpg
#   inflating: all Photos/1580.jpg
#   inflating: all Photos/1581.jpg
#   inflating: all Photos/1582.jpg
#   inflating: all Photos/1583.jpg
#   inflating: all Photos/1584.jpg
#   inflating: all Photos/1585.jpg
#   inflating: all Photos/1586.jpg
#   inflating: all Photos/1587.jpg
#   inflating: all Photos/1588.jpg
#   inflating: all Photos/1589.jpg
#   inflating: all Photos/159.jpg
#   inflating: all Photos/1590.jpg
#   inflating: all Photos/1591.jpg
#   inflating: all Photos/1592.jpg
#   inflating: all Photos/1593.jpg
#   inflating: all Photos/1594.jpg
#   inflating: all Photos/1595.jpg
#   inflating: all Photos/1596.jpg
#   inflating: all Photos/1597.jpg
#   inflating: all Photos/1598.jpg
#   inflating: all Photos/1599.jpg
#   inflating: all Photos/16.jpg
#   inflating: all Photos/160.jpg
#   inflating: all Photos/1600.jpg
#   inflating: all Photos/1601.jpg
#   inflating: all Photos/1602.jpg
#   inflating: all Photos/1603.jpg
#   inflating: all Photos/1604.jpg
#   inflating: all Photos/1605.jpg
#   inflating: all Photos/1606.jpg
#   inflating: all Photos/1607.jpg
#   inflating: all Photos/1608.jpg
#   inflating: all Photos/1609.jpg
#   inflating: all Photos/161.jpg
#   inflating: all Photos/1610.jpg
#   inflating: all Photos/1611.jpg
#   inflating: all Photos/1612.jpg
#   inflating: all Photos/1613.jpg
#   inflating: all Photos/1614.jpg
#   inflating: all Photos/1615.jpg
#   inflating: all Photos/1616.jpg
#   inflating: all Photos/1617.jpg
#   inflating: all Photos/1618.jpg
#   inflating: all Photos/1619.jpg
#   inflating: all Photos/162.jpg
#   inflating: all Photos/1620.jpg
#   inflating: all Photos/1621.jpg
#   inflating: all Photos/1622.jpg
#   inflating: all Photos/1623.jpg
#   inflating: all Photos/1624.jpg
#   inflating: all Photos/1625.jpg
#   inflating: all Photos/1626.jpg
#   inflating: all Photos/1627.jpg
#   inflating: all Photos/1628.jpg
#   inflating: all Photos/1629.jpg
#   inflating: all Photos/163.jpg
#   inflating: all Photos/1630.jpg
#   inflating: all Photos/1631.jpg
#   inflating: all Photos/1632.jpg
#   inflating: all Photos/1633.jpg
#   inflating: all Photos/1634.jpg
#   inflating: all Photos/1635.jpg
#   inflating: all Photos/1636.jpg
#   inflating: all Photos/1637.jpg
#   inflating: all Photos/1638.jpg
#   inflating: all Photos/1639.jpg
#   inflating: all Photos/164.jpg
#   inflating: all Photos/1640.jpg
#   inflating: all Photos/1641.jpg
#   inflating: all Photos/1642.jpg
#   inflating: all Photos/1643.jpg
#   inflating: all Photos/1644.jpg
#   inflating: all Photos/1645.jpg
#   inflating: all Photos/1646.jpg
#   inflating: all Photos/1647.jpg
#   inflating: all Photos/1648.jpg
#   inflating: all Photos/1649.jpg
#   inflating: all Photos/165.jpg
#   inflating: all Photos/1650.jpg
#   inflating: all Photos/1651.jpg
#   inflating: all Photos/1652.jpg
#   inflating: all Photos/1653.jpg
#   inflating: all Photos/1654.jpg
#   inflating: all Photos/1655.jpg
#   inflating: all Photos/1656.jpg
#   inflating: all Photos/1657.jpg
#   inflating: all Photos/1658.jpg
#   inflating: all Photos/1659.jpg
#   inflating: all Photos/166.jpg
#   inflating: all Photos/1660.jpg
#   inflating: all Photos/1661.jpg
#   inflating: all Photos/1662.jpg
#   inflating: all Photos/1663.jpg
#   inflating: all Photos/1664.jpg
#   inflating: all Photos/1665.jpg
#   inflating: all Photos/1666.jpg
#   inflating: all Photos/1667.jpg
#   inflating: all Photos/1668.jpg
#   inflating: all Photos/1669.jpg
#   inflating: all Photos/167.jpg
#   inflating: all Photos/1670.jpg
#   inflating: all Photos/1671.jpg
#   inflating: all Photos/1672.jpg
#   inflating: all Photos/1673.jpg
#   inflating: all Photos/1674.jpg
#   inflating: all Photos/1675.jpg
#   inflating: all Photos/1676.jpg
#   inflating: all Photos/1677.jpg
#   inflating: all Photos/1678.jpg
#   inflating: all Photos/1679.jpg
#   inflating: all Photos/168.jpg
#   inflating: all Photos/1680.jpg
#   inflating: all Photos/1681.jpg
#   inflating: all Photos/1682.jpg
#   inflating: all Photos/1683.jpg
#   inflating: all Photos/1684.jpg
#   inflating: all Photos/1685.jpg
#   inflating: all Photos/1686.jpg
#   inflating: all Photos/1687.jpg
#   inflating: all Photos/1688.jpg
#   inflating: all Photos/1689.jpg
#   inflating: all Photos/169.jpg
#   inflating: all Photos/1690.jpg
#   inflating: all Photos/1691.jpg
#   inflating: all Photos/1692.jpg
#   inflating: all Photos/1693.jpg
#   inflating: all Photos/1694.jpg
#   inflating: all Photos/1695.jpg
#   inflating: all Photos/1696.jpg
#   inflating: all Photos/1697.jpg
#   inflating: all Photos/1698.jpg
#   inflating: all Photos/1699.jpg
#   inflating: all Photos/17.jpg
#   inflating: all Photos/170.jpg
#   inflating: all Photos/1700.jpg
#   inflating: all Photos/1701.jpg
#   inflating: all Photos/1702.png
#   inflating: all Photos/1703.jpg
#   inflating: all Photos/1704.jpg
#   inflating: all Photos/1705.jpg
#   inflating: all Photos/1706.jpg
#   inflating: all Photos/1707.jpg
#   inflating: all Photos/1708.jpg
#   inflating: all Photos/1709.jpg
#   inflating: all Photos/171.jpg
#   inflating: all Photos/1710.jpg
#   inflating: all Photos/1711.jpg
#   inflating: all Photos/1712.jpg
#   inflating: all Photos/1713.jpg
#   inflating: all Photos/1714.jpg
#   inflating: all Photos/1715.jpg
#   inflating: all Photos/1716.jpg
#   inflating: all Photos/1717.jpg
#   inflating: all Photos/1718.jpg
#   inflating: all Photos/1719.jpg
#   inflating: all Photos/172.jpg
#   inflating: all Photos/1720.jpg
#   inflating: all Photos/1721.jpg
#   inflating: all Photos/1722.jpg
#   inflating: all Photos/1723.jpg
#   inflating: all Photos/1724.jpg
#   inflating: all Photos/1725.jpg
#   inflating: all Photos/1726.jpg
#   inflating: all Photos/1727.jpg
#   inflating: all Photos/1728.jpg
#   inflating: all Photos/1729.jpg
#   inflating: all Photos/173.jpg
#   inflating: all Photos/1730.jpg
#   inflating: all Photos/1731.jpg
#   inflating: all Photos/1732.jpg
#   inflating: all Photos/1733.jpg
#   inflating: all Photos/1734.jpg
#   inflating: all Photos/1735.jpg
#   inflating: all Photos/1736.jpg
#   inflating: all Photos/1737.jpg
#   inflating: all Photos/1738.jpg
#   inflating: all Photos/1739.jpg
#   inflating: all Photos/174.jpg
#   inflating: all Photos/1740.jpg
#   inflating: all Photos/1741.jpg
#   inflating: all Photos/1742.jpg
#   inflating: all Photos/1743.jpg
#   inflating: all Photos/1744.jpg
#   inflating: all Photos/1745.jpg
#   inflating: all Photos/1746.jpg
#   inflating: all Photos/1747.jpg
#   inflating: all Photos/1748.jpg
#   inflating: all Photos/1749.jpg
#   inflating: all Photos/175.jpg
#   inflating: all Photos/1750.jpg
#   inflating: all Photos/1751.jpg
#   inflating: all Photos/1752.jpg
#   inflating: all Photos/1753.jpg
#   inflating: all Photos/1754.jpg
#   inflating: all Photos/1755.jpg
#   inflating: all Photos/1756.jpg
#   inflating: all Photos/1757.jpg
#   inflating: all Photos/1758.jpg
#   inflating: all Photos/1759.jpg
#   inflating: all Photos/176.jpg
#   inflating: all Photos/1760.jpg
#   inflating: all Photos/1761.jpg
#   inflating: all Photos/1762.jpg
#   inflating: all Photos/1763.jpg
#   inflating: all Photos/1764.jpg
#   inflating: all Photos/1765.jpg
#   inflating: all Photos/1766.jpg
#   inflating: all Photos/1767.png
#   inflating: all Photos/1768.jpg
#   inflating: all Photos/1769.png
#   inflating: all Photos/177.jpg
#   inflating: all Photos/1770.jpg
#   inflating: all Photos/1771.jpg
#   inflating: all Photos/1772.jpg
#   inflating: all Photos/1773.jpg
#   inflating: all Photos/1774.jpg
#   inflating: all Photos/1775.jpg
#   inflating: all Photos/1776.jpg
#   inflating: all Photos/1777.jpg
#   inflating: all Photos/1778.jpg
#   inflating: all Photos/1779.jpg
#   inflating: all Photos/178.jpg
#   inflating: all Photos/1780.jpg
#   inflating: all Photos/1781.jpg
#   inflating: all Photos/1782.jpg
#   inflating: all Photos/1783.jpg
#   inflating: all Photos/1784.jpg
#   inflating: all Photos/1785.jpg
#   inflating: all Photos/1786.jpg
#   inflating: all Photos/1787.jpg
#   inflating: all Photos/1788.jpg
#   inflating: all Photos/1789.jpg
#   inflating: all Photos/179.jpg
#   inflating: all Photos/1790.jpg
#   inflating: all Photos/1791.jpg
#   inflating: all Photos/1792.jpg
#   inflating: all Photos/1793.jpg
#   inflating: all Photos/1794.jpg
#   inflating: all Photos/1795.jpg
#   inflating: all Photos/1796.jpg
#   inflating: all Photos/1797.jpg
#   inflating: all Photos/1798.jpg
#   inflating: all Photos/1799.jpg
#   inflating: all Photos/18.jpg
#   inflating: all Photos/180.jpg
#   inflating: all Photos/1800.jpg
#   inflating: all Photos/1801.jpg
#   inflating: all Photos/1802.jpg
#   inflating: all Photos/1803.jpg
#   inflating: all Photos/1804.jpg
#   inflating: all Photos/1805.jpg
#   inflating: all Photos/1806.jpg
#   inflating: all Photos/1807.jpg
#   inflating: all Photos/1808.jpg
#   inflating: all Photos/1809.jpg
#   inflating: all Photos/181.jpg
#   inflating: all Photos/1810.jpg
#   inflating: all Photos/1811.jpg
#   inflating: all Photos/1812.jpg
#   inflating: all Photos/1813.jpg
#   inflating: all Photos/1814.jpg
#   inflating: all Photos/1815.jpg
#   inflating: all Photos/1816.jpg
#   inflating: all Photos/1817.jpg
#   inflating: all Photos/1818.jpg
#   inflating: all Photos/1819.jpg
#   inflating: all Photos/182.jpg
#   inflating: all Photos/1820.jpg
#   inflating: all Photos/1821.jpg
#   inflating: all Photos/1822.jpg
#   inflating: all Photos/1823.jpg
#   inflating: all Photos/1824.jpg
#   inflating: all Photos/1825.jpg
#   inflating: all Photos/1826.jpg
#   inflating: all Photos/1827.jpg
#   inflating: all Photos/1828.jpg
#   inflating: all Photos/1829.jpg
#   inflating: all Photos/183.jpg
#   inflating: all Photos/1830.jpg
#   inflating: all Photos/1831.jpg
#   inflating: all Photos/1832.jpg
#   inflating: all Photos/1833.jpg
#   inflating: all Photos/1834.jpg
#   inflating: all Photos/1835.jpg
#   inflating: all Photos/1836.jpg
#   inflating: all Photos/1837.jpg
#   inflating: all Photos/1838.jpg
#   inflating: all Photos/1839.jpg
#   inflating: all Photos/184.jpg
#   inflating: all Photos/1840.jpg
#   inflating: all Photos/1841.jpg
#   inflating: all Photos/1842.jpg
#   inflating: all Photos/1843.jpg
#   inflating: all Photos/1844.jpg
#   inflating: all Photos/1845.jpg
#   inflating: all Photos/1846.jpg
#   inflating: all Photos/1847.jpg
#   inflating: all Photos/1848.jpg
#   inflating: all Photos/1849.jpg
#   inflating: all Photos/185.jpg
#   inflating: all Photos/1850.jpg
#   inflating: all Photos/1851.jpg
#   inflating: all Photos/1852.jpg
#   inflating: all Photos/1853.jpg
#   inflating: all Photos/1854.jpg
#   inflating: all Photos/1855.jpg
#   inflating: all Photos/1856.jpg
#   inflating: all Photos/1857.jpg
#   inflating: all Photos/1858.jpg
#   inflating: all Photos/1859.jpg
#   inflating: all Photos/186.jpg
#   inflating: all Photos/1860.jpg
#   inflating: all Photos/1861.jpg
#   inflating: all Photos/1862.jpg
#   inflating: all Photos/1863.jpg
#   inflating: all Photos/1864.jpg
#   inflating: all Photos/1865.jpg
#   inflating: all Photos/1866.jpg
#   inflating: all Photos/1867.jpg
#   inflating: all Photos/1868.jpg
#   inflating: all Photos/1869.jpg
#   inflating: all Photos/187.jpg
#   inflating: all Photos/1870.jpg
#   inflating: all Photos/1871.jpg
#   inflating: all Photos/1872.jpg
#   inflating: all Photos/1873.jpg
#   inflating: all Photos/1874.jpg
#   inflating: all Photos/1875.jpg
#   inflating: all Photos/1876.jpg
#   inflating: all Photos/1877.jpg
#   inflating: all Photos/1878.jpg
#   inflating: all Photos/1879.jpg
#   inflating: all Photos/188.jpg
#   inflating: all Photos/1880.jpg
#   inflating: all Photos/1881.jpg
#   inflating: all Photos/1882.jpg
#   inflating: all Photos/1883.jpg
#   inflating: all Photos/1884.jpg
#   inflating: all Photos/1885.jpg
#   inflating: all Photos/1886.jpg
#   inflating: all Photos/1887.jpg
#   inflating: all Photos/1888.jpg
#   inflating: all Photos/1889.jpg
#   inflating: all Photos/189.jpg
#   inflating: all Photos/1890.jpg
#   inflating: all Photos/1891.jpg
#   inflating: all Photos/1892.jpg
#   inflating: all Photos/1893.jpg
#   inflating: all Photos/1894.jpg
#   inflating: all Photos/1895.jpg
#   inflating: all Photos/1896.jpg
#   inflating: all Photos/1897.jpg
#   inflating: all Photos/1898.jpg
#   inflating: all Photos/1899.jpg
#   inflating: all Photos/19.jpg
#   inflating: all Photos/190.jpg
#   inflating: all Photos/1900.jpg
#   inflating: all Photos/1901.jpg
#   inflating: all Photos/1902.jpg
#   inflating: all Photos/1903.jpg
#   inflating: all Photos/1904.jpg
#   inflating: all Photos/1905.jpg
#   inflating: all Photos/1906.jpg
#   inflating: all Photos/1907.jpg
#   inflating: all Photos/1908.jpg
#   inflating: all Photos/1909.jpg
#   inflating: all Photos/191.jpg
#   inflating: all Photos/1910.jpg
#   inflating: all Photos/1911.jpg
#   inflating: all Photos/1912.jpg
#   inflating: all Photos/1913.jpg
#   inflating: all Photos/1914.jpg
#   inflating: all Photos/1915.jpg
#   inflating: all Photos/1916.jpg
#   inflating: all Photos/1917.jpg
#   inflating: all Photos/1918.jpg
#   inflating: all Photos/1919.jpg
#   inflating: all Photos/192.jpg
#   inflating: all Photos/1920.jpg
#   inflating: all Photos/1921.jpg
#   inflating: all Photos/1922.jpg
#   inflating: all Photos/1923.jpg
#   inflating: all Photos/1924.jpg
#   inflating: all Photos/1925.jpg
#   inflating: all Photos/1926.jpg
#   inflating: all Photos/1927.jpg
#   inflating: all Photos/1928.jpg
#   inflating: all Photos/1929.jpg
#   inflating: all Photos/193.jpg
#   inflating: all Photos/1930.jpg
#   inflating: all Photos/1931.jpg
#   inflating: all Photos/1932.jpg
#   inflating: all Photos/1933.jpg
#   inflating: all Photos/1934.jpg
#   inflating: all Photos/1935.jpg
#   inflating: all Photos/1936.jpg
#   inflating: all Photos/1937.jpg
#   inflating: all Photos/1938.jpg
#   inflating: all Photos/1939.jpg
#   inflating: all Photos/194.jpg
#   inflating: all Photos/1940.jpg
#   inflating: all Photos/1941.jpg
#   inflating: all Photos/1942.jpg
#   inflating: all Photos/1943.jpg
#   inflating: all Photos/1944.jpg
#   inflating: all Photos/1945.jpg
#   inflating: all Photos/1946.jpg
#   inflating: all Photos/1947.jpg
#   inflating: all Photos/1948.jpg
#   inflating: all Photos/1949.jpg
#   inflating: all Photos/195.jpg
#   inflating: all Photos/1950.jpg
#   inflating: all Photos/1951.jpg
#   inflating: all Photos/1952.jpg
#   inflating: all Photos/1953.jpg
#   inflating: all Photos/1954.jpg
#   inflating: all Photos/1955.jpg
#   inflating: all Photos/1956.jpg
#   inflating: all Photos/1957.jpg
#   inflating: all Photos/1958.jpg
#   inflating: all Photos/1959.jpg
#   inflating: all Photos/196.jpg
#   inflating: all Photos/1960.jpg
#   inflating: all Photos/1961.jpg
#   inflating: all Photos/1962.jpg
#   inflating: all Photos/1963.jpg
#   inflating: all Photos/1964.jpg
#   inflating: all Photos/1965.jpg
#   inflating: all Photos/1966.jpg
#   inflating: all Photos/1967.jpg
#   inflating: all Photos/1968.jpg
#   inflating: all Photos/1969.jpg
#   inflating: all Photos/197.jpg
#   inflating: all Photos/1970.jpg
#   inflating: all Photos/1971.jpg
#   inflating: all Photos/1972.jpg
#   inflating: all Photos/1973.jpg
#   inflating: all Photos/1974.jpg
#   inflating: all Photos/1975.jpg
#   inflating: all Photos/1976.jpg
#   inflating: all Photos/1977.jpg
#   inflating: all Photos/1978.jpg
#   inflating: all Photos/1979.jpg
#   inflating: all Photos/198.jpg
#   inflating: all Photos/1980.jpg
#   inflating: all Photos/1981.jpg
#   inflating: all Photos/1982.jpg
#   inflating: all Photos/1983.jpg
#   inflating: all Photos/1984.jpg
#   inflating: all Photos/1985.jpg
#   inflating: all Photos/1986.jpg
#   inflating: all Photos/1987.jpg
#   inflating: all Photos/1988.jpg
#   inflating: all Photos/1989.jpg
#   inflating: all Photos/199.jpg
#   inflating: all Photos/1990.jpg
#   inflating: all Photos/1991.jpg
#   inflating: all Photos/1992.jpg
#   inflating: all Photos/1993.jpg
#   inflating: all Photos/1994.jpg
#   inflating: all Photos/1995.jpg
#   inflating: all Photos/1996.jpg
#   inflating: all Photos/1997.jpg
#   inflating: all Photos/1998.jpg
#   inflating: all Photos/1999.jpg
#   inflating: all Photos/2.jpg
#   inflating: all Photos/20.jpg
#   inflating: all Photos/200.jpg
#   inflating: all Photos/2000.jpg
#   inflating: all Photos/2001.jpg
#   inflating: all Photos/2002.jpg
#   inflating: all Photos/2003.jpg
#   inflating: all Photos/2004.jpg
#   inflating: all Photos/2005.jpg
#   inflating: all Photos/2006.jpg
#   inflating: all Photos/2007.jpg
#   inflating: all Photos/2008.jpg
#   inflating: all Photos/2009.jpg
#   inflating: all Photos/201.jpg
#   inflating: all Photos/2010.jpg
#   inflating: all Photos/2011.jpg
#   inflating: all Photos/2012.jpg
#   inflating: all Photos/2013.jpg
#   inflating: all Photos/2014.jpg
#   inflating: all Photos/2015.jpg
#   inflating: all Photos/2016.jpg
#   inflating: all Photos/2017.jpg
#   inflating: all Photos/2018.jpg
#   inflating: all Photos/2019.jpg
#   inflating: all Photos/202.jpg
#   inflating: all Photos/2020.jpg
#   inflating: all Photos/2021.jpg
#   inflating: all Photos/2022.jpg
#   inflating: all Photos/2023.jpg
#   inflating: all Photos/2024.jpg
#   inflating: all Photos/2025.jpg
#   inflating: all Photos/2026.jpg
#   inflating: all Photos/2027.jpg
#   inflating: all Photos/2028.jpg
#   inflating: all Photos/2029.jpg
#   inflating: all Photos/203.jpg
#   inflating: all Photos/2030.jpg
#   inflating: all Photos/2031.jpg
#   inflating: all Photos/2032.jpg
#   inflating: all Photos/2033.jpg
#   inflating: all Photos/2034.jpg
#   inflating: all Photos/2035.jpg
#   inflating: all Photos/2036.jpg
#   inflating: all Photos/2037.jpg
#   inflating: all Photos/2038.jpg
#   inflating: all Photos/2039.jpg
#   inflating: all Photos/204.jpg
#   inflating: all Photos/2040.jpg
#   inflating: all Photos/2041.jpg
#   inflating: all Photos/2042.jpg
#   inflating: all Photos/2043.jpg
#   inflating: all Photos/2044.jpg
#   inflating: all Photos/2045.jpg
#   inflating: all Photos/2046.jpg
#   inflating: all Photos/2047.jpg
#   inflating: all Photos/2048.jpg
#   inflating: all Photos/2049.jpg
#   inflating: all Photos/205.jpg
#   inflating: all Photos/2050.jpg
#   inflating: all Photos/2051.jpg
#   inflating: all Photos/2052.jpg
#   inflating: all Photos/2053.jpg
#   inflating: all Photos/2054.jpg
#   inflating: all Photos/2055.jpg
#   inflating: all Photos/2056.jpg
#   inflating: all Photos/2057.jpg
#   inflating: all Photos/2058.jpg
#   inflating: all Photos/2059.jpg
#   inflating: all Photos/206.jpg
#   inflating: all Photos/2060.jpg
#   inflating: all Photos/2061.jpg
#   inflating: all Photos/2062.jpg
#   inflating: all Photos/2063.jpg
#   inflating: all Photos/2064.jpg
#   inflating: all Photos/2065.jpg
#   inflating: all Photos/2066.jpg
#   inflating: all Photos/2067.jpg
#   inflating: all Photos/2068.jpg
#   inflating: all Photos/2069.jpg
#   inflating: all Photos/207.jpg
#   inflating: all Photos/2070.jpg
#   inflating: all Photos/2071.jpg
#   inflating: all Photos/2072.jpg
#   inflating: all Photos/2073.jpg
#   inflating: all Photos/2074.jpg
#   inflating: all Photos/2075.jpg
#   inflating: all Photos/2076.jpg
#   inflating: all Photos/2077.jpg
#   inflating: all Photos/2078.jpg
#   inflating: all Photos/2079.jpg
#   inflating: all Photos/208.jpg
#   inflating: all Photos/2080.jpg
#   inflating: all Photos/2081.jpg
#   inflating: all Photos/2082.jpg
#   inflating: all Photos/2083.jpg
#   inflating: all Photos/2084.jpg
#   inflating: all Photos/2085.jpg
#   inflating: all Photos/2086.jpg
#   inflating: all Photos/2087.jpg
#   inflating: all Photos/2088.jpg
#   inflating: all Photos/2089.jpg
#   inflating: all Photos/209.jpg
#   inflating: all Photos/2090.jpg
#   inflating: all Photos/2091.jpg
#   inflating: all Photos/2092.jpg
#   inflating: all Photos/2093.jpg
#   inflating: all Photos/2094.jpg
#   inflating: all Photos/2095.jpg
#   inflating: all Photos/2096.jpg
#   inflating: all Photos/2097.jpg
#   inflating: all Photos/2098.jpg
#   inflating: all Photos/2099.jpg
#   inflating: all Photos/21.jpg
#   inflating: all Photos/210.jpg
#   inflating: all Photos/2100.jpg
#   inflating: all Photos/2101.jpg
#   inflating: all Photos/2102.jpg
#   inflating: all Photos/2103.jpg
#   inflating: all Photos/2104.jpg
#   inflating: all Photos/2105.jpg
#   inflating: all Photos/2106.jpg
#   inflating: all Photos/2107.jpg
#   inflating: all Photos/2108.jpg
#   inflating: all Photos/2109.jpg
#   inflating: all Photos/211.jpg
#   inflating: all Photos/2110.jpg
#   inflating: all Photos/2111.jpg
#   inflating: all Photos/2112.jpg
#   inflating: all Photos/2113.jpg
#   inflating: all Photos/2114.jpg
#   inflating: all Photos/2115.jpg
#   inflating: all Photos/2116.jpg
#   inflating: all Photos/2117.jpg
#   inflating: all Photos/2118.jpg
#   inflating: all Photos/2119.jpg
#   inflating: all Photos/212.jpg
#   inflating: all Photos/2120.jpg
#   inflating: all Photos/2121.jpg
#   inflating: all Photos/2122.jpg
#   inflating: all Photos/2123.jpg
#   inflating: all Photos/2124.jpg
#   inflating: all Photos/2125.jpg
#   inflating: all Photos/2126.jpg
#   inflating: all Photos/2127.jpg
#   inflating: all Photos/2128.jpg
#   inflating: all Photos/2129.jpg
#   inflating: all Photos/213.jpg
#   inflating: all Photos/2130.jpg
#   inflating: all Photos/2131.jpg
#   inflating: all Photos/2132.jpg
#   inflating: all Photos/2133.jpg
# ...
#   inflating: all Photos/622.jpg
#   inflating: all Photos/623.jpg
#   inflating: all Photos/624.jpg
#   inflating: all Photos/625.jpg
#   inflating: all Photos/626.jpg
#   inflating: all Photos/627.jpg
#   inflating: all Photos/628.jpg
#   inflating: all Photos/629.jpg
#   inflating: all Photos/63.jpg
#   inflating: all Photos/630.jpg
#   inflating: all Photos/631.jpg
#   inflating: all Photos/632.jpg
#   inflating: all Photos/633.jpg
#   inflating: all Photos/634.jpg
#   inflating: all Photos/635.jpg
#   inflating: all Photos/636.jpg
#   inflating: all Photos/637.jpg
#   inflating: all Photos/638.jpg
#   inflating: all Photos/639.jpg
#   inflating: all Photos/64.jpg
#   inflating: all Photos/640.jpg
#   inflating: all Photos/641.jpg
#   inflating: all Photos/642.jpg
#   inflating: all Photos/643.jpg
#   inflating: all Photos/644.jpg
#   inflating: all Photos/645.jpg
#   inflating: all Photos/646.jpg
#   inflating: all Photos/647.jpg
#   inflating: all Photos/648.jpg
#   inflating: all Photos/649.jpg
#   inflating: all Photos/65.jpg
#   inflating: all Photos/650.jpg
#   inflating: all Photos/651.jpg
#   inflating: all Photos/652.jpg
#   inflating: all Photos/653.jpg
#   inflating: all Photos/654.jpg
#   inflating: all Photos/655.jpg
#   inflating: all Photos/656.jpg
#   inflating: all Photos/657.jpg
#   inflating: all Photos/658.jpg
#   inflating: all Photos/659.jpg
#   inflating: all Photos/66.jpg
#   inflating: all Photos/660.jpg
#   inflating: all Photos/661.jpg
#   inflating: all Photos/662.jpg
#   inflating: all Photos/663.jpg
#   inflating: all Photos/664.jpg
#   inflating: all Photos/665.jpg
#   inflating: all Photos/666.jpg
#   inflating: all Photos/667.jpg
#   inflating: all Photos/668.jpg
#   inflating: all Photos/669.jpg
#   inflating: all Photos/67.jpg
#   inflating: all Photos/670.jpg
#   inflating: all Photos/671.jpg
#   inflating: all Photos/672.jpg
#   inflating: all Photos/673.jpg
#   inflating: all Photos/674.jpg
#   inflating: all Photos/675.jpg
#   inflating: all Photos/676.jpg
#   inflating: all Photos/677.jpg
#   inflating: all Photos/678.jpg
#   inflating: all Photos/679.jpg
#   inflating: all Photos/68.jpg
#   inflating: all Photos/680.jpg
#   inflating: all Photos/681.jpg
#   inflating: all Photos/682.jpg
#   inflating: all Photos/683.jpg
#   inflating: all Photos/684.jpg
#   inflating: all Photos/685.jpg
#   inflating: all Photos/686.jpg
#   inflating: all Photos/687.jpg
#   inflating: all Photos/688.jpg
#   inflating: all Photos/689.jpg
#   inflating: all Photos/69.jpg
#   inflating: all Photos/690.jpg
#   inflating: all Photos/691.jpg
#   inflating: all Photos/692.jpg
#   inflating: all Photos/693.jpg
#   inflating: all Photos/694.jpg
#   inflating: all Photos/695.jpg
#   inflating: all Photos/696.jpg
#   inflating: all Photos/697.jpg
#   inflating: all Photos/698.jpg
#   inflating: all Photos/699.jpg
#   inflating: all Photos/7.jpg
#   inflating: all Photos/70.jpg
#   inflating: all Photos/700.jpg
#   inflating: all Photos/701.jpg
#   inflating: all Photos/702.jpg
#   inflating: all Photos/703.jpg
#   inflating: all Photos/704.jpg
#   inflating: all Photos/705.jpg
#   inflating: all Photos/706.jpg
#   inflating: all Photos/707.jpg
#   inflating: all Photos/708.jpg
#   inflating: all Photos/709.jpg
#   inflating: all Photos/71.jpg
#   inflating: all Photos/710.jpg
#   inflating: all Photos/711.jpg
#   inflating: all Photos/712.jpg
#   inflating: all Photos/713.jpg
#   inflating: all Photos/714.jpg
#   inflating: all Photos/715.jpg
#   inflating: all Photos/716.jpg
#   inflating: all Photos/717.jpg
#   inflating: all Photos/718.jpg
#   inflating: all Photos/719.jpg
#   inflating: all Photos/72.jpg
#   inflating: all Photos/720.jpg
#   inflating: all Photos/721.jpg
#   inflating: all Photos/722.jpg
#   inflating: all Photos/723.jpg
#   inflating: all Photos/724.jpg
#   inflating: all Photos/725.jpg
#   inflating: all Photos/726.jpg
#   inflating: all Photos/727.jpg
#   inflating: all Photos/728.jpg
#   inflating: all Photos/729.jpg
#   inflating: all Photos/73.jpg
#   inflating: all Photos/730.jpg
#   inflating: all Photos/731.jpg
#   inflating: all Photos/732.jpg
#   inflating: all Photos/733.jpg
#   inflating: all Photos/734.jpg
#   inflating: all Photos/735.jpg
#   inflating: all Photos/736.jpg
#   inflating: all Photos/737.jpg
#   inflating: all Photos/738.jpg
#   inflating: all Photos/739.jpg
#   inflating: all Photos/74.jpg
#   inflating: all Photos/740.jpg
#   inflating: all Photos/741.jpg
#   inflating: all Photos/742.jpg
#   inflating: all Photos/743.jpg
#   inflating: all Photos/744.jpg
#   inflating: all Photos/745.jpg
#   inflating: all Photos/746.jpg
#   inflating: all Photos/747.jpg
#   inflating: all Photos/748.jpg
#   inflating: all Photos/749.jpg
#   inflating: all Photos/75.jpg
#   inflating: all Photos/750.jpg
#   inflating: all Photos/751.jpg
#   inflating: all Photos/752.jpg
#   inflating: all Photos/753.jpg
#   inflating: all Photos/754.jpg
#   inflating: all Photos/755.jpg
#   inflating: all Photos/756.jpg
#   inflating: all Photos/757.jpg
#   inflating: all Photos/758.jpg
#   inflating: all Photos/759.jpg
#   inflating: all Photos/76.jpg
#   inflating: all Photos/760.jpg
#   inflating: all Photos/761.jpg
#   inflating: all Photos/762.jpg
#   inflating: all Photos/763.jpg
#   inflating: all Photos/764.jpg
#   inflating: all Photos/765.jpg
#   inflating: all Photos/766.jpg
#   inflating: all Photos/767.jpg
#   inflating: all Photos/768.jpg
#   inflating: all Photos/769.jpg
#   inflating: all Photos/77.jpg
#   inflating: all Photos/770.jpg
#   inflating: all Photos/771.jpg
#   inflating: all Photos/772.jpg
#   inflating: all Photos/773.jpg
#   inflating: all Photos/774.jpg
#   inflating: all Photos/775.jpg
#   inflating: all Photos/776.jpg
#   inflating: all Photos/777.jpg
#   inflating: all Photos/778.jpg
#   inflating: all Photos/779.jpg
#   inflating: all Photos/78.jpg
#   inflating: all Photos/780.jpg
#   inflating: all Photos/781.jpg
#   inflating: all Photos/782.jpg
#   inflating: all Photos/783.jpg
#   inflating: all Photos/784.jpg
#   inflating: all Photos/785.jpg
#   inflating: all Photos/786.jpg
#   inflating: all Photos/787.jpg
#   inflating: all Photos/788.jpg
#   inflating: all Photos/789.jpg
#   inflating: all Photos/79.jpg
#   inflating: all Photos/790.jpg
#   inflating: all Photos/791.jpg
#   inflating: all Photos/792.jpg
#   inflating: all Photos/793.jpg
#   inflating: all Photos/794.jpg
#   inflating: all Photos/795.jpg
#   inflating: all Photos/796.jpg
#   inflating: all Photos/797.jpg
#   inflating: all Photos/798.jpg
#   inflating: all Photos/799.jpg
#   inflating: all Photos/8.jpg
#   inflating: all Photos/80.jpg
#   inflating: all Photos/800.jpg
#   inflating: all Photos/801.jpg
#   inflating: all Photos/802.jpg
#   inflating: all Photos/803.jpg
#   inflating: all Photos/804.jpg
#   inflating: all Photos/805.jpg
#   inflating: all Photos/806.jpg
#   inflating: all Photos/807.jpg
#   inflating: all Photos/808.jpg
#   inflating: all Photos/809.jpg
#   inflating: all Photos/81.jpg
#   inflating: all Photos/810.jpg
#   inflating: all Photos/811.jpg
#   inflating: all Photos/812.jpg
#   inflating: all Photos/813.jpg
#   inflating: all Photos/814.jpg
#   inflating: all Photos/815.jpg
#   inflating: all Photos/816.jpg
#   inflating: all Photos/817.jpg
#   inflating: all Photos/818.jpg
#   inflating: all Photos/819.jpg
#   inflating: all Photos/82.jpg
#   inflating: all Photos/820.jpg
#   inflating: all Photos/821.jpg
#   inflating: all Photos/822.jpg
#   inflating: all Photos/823.jpg
#   inflating: all Photos/824.jpg
#   inflating: all Photos/825.jpg
#   inflating: all Photos/826.jpg
#   inflating: all Photos/827.jpg
#   inflating: all Photos/828.jpg
#   inflating: all Photos/829.jpg
#   inflating: all Photos/83.jpg
#   inflating: all Photos/830.jpg
#   inflating: all Photos/831.jpg
#   inflating: all Photos/832.jpg
#   inflating: all Photos/833.jpg
#   inflating: all Photos/834.jpg
#   inflating: all Photos/835.jpg
#   inflating: all Photos/836.jpg
#   inflating: all Photos/837.jpg
#   inflating: all Photos/838.jpg
#   inflating: all Photos/839.jpg
#   inflating: all Photos/84.jpg
#   inflating: all Photos/840.jpg
#   inflating: all Photos/841.jpg
#   inflating: all Photos/842.jpg
#   inflating: all Photos/843.jpg
#   inflating: all Photos/844.jpg
#   inflating: all Photos/845.jpg
#   inflating: all Photos/846.jpg
#   inflating: all Photos/847.jpg
#   inflating: all Photos/848.jpg
#   inflating: all Photos/849.jpg
#   inflating: all Photos/85.jpg
#   inflating: all Photos/850.jpg
#   inflating: all Photos/851.jpg
#   inflating: all Photos/852.jpg
#   inflating: all Photos/853.jpg
#   inflating: all Photos/854.jpg
#   inflating: all Photos/855.jpg
#   inflating: all Photos/856.jpg
#   inflating: all Photos/857.jpg
#   inflating: all Photos/858.jpg
#   inflating: all Photos/859.jpg
#   inflating: all Photos/86.jpg
#   inflating: all Photos/860.jpg
#   inflating: all Photos/861.jpg
#   inflating: all Photos/862.jpg
#   inflating: all Photos/863.jpg
#   inflating: all Photos/864.jpg
#   inflating: all Photos/865.jpg
#   inflating: all Photos/866.jpg
#   inflating: all Photos/867.jpg
#   inflating: all Photos/868.jpg
#   inflating: all Photos/869.jpg
#   inflating: all Photos/87.jpg
#   inflating: all Photos/870.jpg
#   inflating: all Photos/871.jpg
#   inflating: all Photos/872.jpg
#   inflating: all Photos/873.jpg
#   inflating: all Photos/874.jpg
#   inflating: all Photos/875.jpg
#   inflating: all Photos/876.jpg
#   inflating: all Photos/877.jpg
#   inflating: all Photos/878.jpg
#   inflating: all Photos/879.jpg
#   inflating: all Photos/88.jpg
#   inflating: all Photos/880.jpg
#   inflating: all Photos/881.jpg
#   inflating: all Photos/882.jpg
#   inflating: all Photos/883.jpg
#   inflating: all Photos/884.jpg
#   inflating: all Photos/885.jpg
#   inflating: all Photos/886.jpg
#   inflating: all Photos/887.jpg
#   inflating: all Photos/888.jpg
#   inflating: all Photos/889.jpg
#   inflating: all Photos/89.jpg
#   inflating: all Photos/890.jpg
#   inflating: all Photos/891.jpg
#   inflating: all Photos/892.jpg
#   inflating: all Photos/893.jpg
#   inflating: all Photos/894.jpg
#   inflating: all Photos/895.jpg
#   inflating: all Photos/896.jpg
#   inflating: all Photos/897.jpg
#   inflating: all Photos/898.jpg
#   inflating: all Photos/899.jpg
#   inflating: all Photos/9.jpg
#   inflating: all Photos/90.jpg
#   inflating: all Photos/900.jpg
#   inflating: all Photos/901.jpg
#   inflating: all Photos/902.jpg
#   inflating: all Photos/903.jpg
#   inflating: all Photos/904.jpg
#   inflating: all Photos/905.jpg
#   inflating: all Photos/906.jpg
#   inflating: all Photos/907.jpg
#   inflating: all Photos/908.jpg
#   inflating: all Photos/909.jpg
#   inflating: all Photos/91.jpg
#   inflating: all Photos/910.jpg
#   inflating: all Photos/911.jpg
#   inflating: all Photos/912.jpg
#   inflating: all Photos/913.jpg
#   inflating: all Photos/914.jpg
#   inflating: all Photos/915.jpg
#   inflating: all Photos/916.jpg
#   inflating: all Photos/917.jpg
#   inflating: all Photos/918.jpg
#   inflating: all Photos/919.jpg
#   inflating: all Photos/92.jpg
#   inflating: all Photos/920.jpg
#   inflating: all Photos/921.jpg
#   inflating: all Photos/922.jpg
#   inflating: all Photos/923.jpg
#   inflating: all Photos/924.jpg
#   inflating: all Photos/925.jpg
#   inflating: all Photos/926.jpg
#   inflating: all Photos/927.jpg
#   inflating: all Photos/928.jpg
#   inflating: all Photos/929.jpg
#   inflating: all Photos/93.jpg
#   inflating: all Photos/930.jpg
#   inflating: all Photos/931.jpg
#   inflating: all Photos/932.jpg
#   inflating: all Photos/933.jpg
#   inflating: all Photos/934.jpg
#   inflating: all Photos/935.jpg
#   inflating: all Photos/936.jpg
#   inflating: all Photos/937.jpg
#   inflating: all Photos/938.jpg
#   inflating: all Photos/939.jpg
#   inflating: all Photos/94.jpg
#   inflating: all Photos/940.jpg
#   inflating: all Photos/941.jpg
#   inflating: all Photos/942.jpg
#   inflating: all Photos/943.jpg
#   inflating: all Photos/944.jpg
#   inflating: all Photos/945.jpg
#   inflating: all Photos/946.jpg
#   inflating: all Photos/947.jpg
#   inflating: all Photos/948.jpg
#   inflating: all Photos/949.jpg
#   inflating: all Photos/95.jpg
#   inflating: all Photos/950.jpg
#   inflating: all Photos/951.jpg
#   inflating: all Photos/952.jpg
#   inflating: all Photos/953.jpg
#   inflating: all Photos/954.jpg
#   inflating: all Photos/955.jpg
#   inflating: all Photos/956.jpg
#   inflating: all Photos/957.jpg
#   inflating: all Photos/958.jpg
#   inflating: all Photos/959.jpg
#   inflating: all Photos/96.jpg
#   inflating: all Photos/960.jpg
#   inflating: all Photos/961.jpg
#   inflating: all Photos/962.jpg
#   inflating: all Photos/963.jpg
#   inflating: all Photos/964.jpg
#   inflating: all Photos/965.jpg
#   inflating: all Photos/966.jpg
#   inflating: all Photos/967.jpg
#   inflating: all Photos/968.jpg
#   inflating: all Photos/969.jpg
#   inflating: all Photos/97.jpg
#   inflating: all Photos/970.jpg
#   inflating: all Photos/971.jpg
#   inflating: all Photos/972.jpg
#   inflating: all Photos/973.jpg
#   inflating: all Photos/974.jpg
#   inflating: all Photos/975.jpg
#   inflating: all Photos/976.jpg
#   inflating: all Photos/977.jpg
#   inflating: all Photos/978.jpg
#   inflating: all Photos/979.jpg
#   inflating: all Photos/98.jpg
#   inflating: all Photos/980.jpg
#   inflating: all Photos/981.jpg
#   inflating: all Photos/982.jpg
#   inflating: all Photos/983.jpg
#   inflating: all Photos/984.jpg
#   inflating: all Photos/985.jpg
#   inflating: all Photos/986.jpg
#   inflating: all Photos/987.jpg
#   inflating: all Photos/988.jpg
#   inflating: all Photos/989.jpg
#   inflating: all Photos/99.jpg
#   inflating: all Photos/990.jpg
#   inflating: all Photos/991.jpg
#   inflating: all Photos/992.jpg
#   inflating: all Photos/993.jpg
#   inflating: all Photos/994.jpg
#   inflating: all Photos/995.jpg
#   inflating: all Photos/996.jpg
#   inflating: all Photos/997.jpg
#   inflating: all Photos/998.jpg
#   inflating: all Photos/999.jpg
#   inflating: all Photos/test.pkl
#   inflating: all Photos/train.pkl
#   inflating: all Photos/valid.pkl

# %%
pip install transformers torchvision pandas scikit-learn
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.41.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from torchvision import transforms
from PIL import Image
import os

# Load the CSV file
csv_path = '/kaggle/input/postcomm/Dataset_text.csv'
df = pd.read_csv(csv_path)

# Verify column names
print(df.columns)

# Drop unnecessary columns if they exist
columns_to_drop = [col for col in ['Source', 'Domain', 'Unnamed: 5'] if col in df.columns]
df = df.drop(columns_to_drop, axis=1)

# Shuffle the dataframe
df = shuffle(df, random_state=42)

# Split the dataset
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

train_data, val_test = train_test_split(df, train_size=train_ratio, random_state=42)
valid_data, test_data = train_test_split(val_test, train_size=val_ratio / (val_ratio + test_ratio), random_state=42)
# Out:
# Index(['Image id', 'Caption', 'Label', 'Source', 'Domain', 'Unnamed: 5'], dtype='object')

# %%
"""image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])"""
# Out:
# 'image_transforms = transforms.Compose([\n    transforms.Resize((224, 224)),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),\n])'

# %%
"""tokenizer = BertTokenizer.from_pretrained('sagorsarker/bangla-bert-base')"""
# Out:
# "tokenizer = BertTokenizer.from_pretrained('sagorsarker/bangla-bert-base')"

# %%
"""class MultimodalDataset(Dataset):
    def __init__(self, dataframe, images_folder, tokenizer, image_transforms, feature_extractor):
        self.dataframe = dataframe
        self.images_folder = images_folder
        self.tokenizer = tokenizer
        self.image_transforms = image_transforms
        self.feature_extractor = feature_extractor

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        text = row['Caption']
        label = row['Label']
        image_id = row['Image id']

        image_path_jpg = os.path.join(self.images_folder, f"{image_id}.jpg")
        image_path_png = os.path.join(self.images_folder, f"{image_id}.png")

        if os.path.exists(image_path_jpg):
            image_path = image_path_jpg
        elif os.path.exists(image_path_png):
            image_path = image_path_png
        else:
            raise FileNotFoundError(f"Image {image_id} not found with .jpg or .png extension")

        image = Image.open(image_path).convert('RGB')
        image = self.image_transforms(image)
        pixel_values = self.feature_extractor(images=image, return_tensors="pt").pixel_values.squeeze()

        text_inputs = self.tokenizer(text, return_tensors='pt', padding='max_length', truncation=True, max_length=128)

        label = int(label)
        assert 0 <= label < 2, f"Label {label} out of range"

        return {
            'original_text': text,
            'original_label': label,
            'input_ids': text_inputs['input_ids'].squeeze(),
            'attention_mask': text_inputs['attention_mask'].squeeze(),
            'pixel_values': pixel_values,
            'label': torch.tensor(label, dtype=torch.long)
        }
"""
# Out:
# 'class MultimodalDataset(Dataset):\n    def __init__(self, dataframe, images_folder, tokenizer, image_transforms, feature_extractor):\n        self.dataframe = dataframe\n        self.images_folder = images_folder\n        self.tokenizer = tokenizer\n        self.image_transforms = image_transforms\n        self.feature_extractor = feature_extractor\n\n    def __len__(self):\n        return len(self.dataframe)\n\n    def __getitem__(self, idx):\n        row = self.dataframe.iloc[idx]\n        text = row[\'Caption\']\n        label = row[\'Label\']\n        image_id = row[\'Image id\']\n\n        image_path_jpg = os.path.join(self.images_folder, f"{image_id}.jpg")\n        image_path_png = os.path.join(self.images_folder, f"{image_id}.png")\n\n        if os.path.exists(image_path_jpg):\n            image_path = image_path_jpg\n        elif os.path.exists(image_path_png):\n            image_path = image_path_png\n        else:\n            raise FileNotFoundError(f"Image {image_id} not found with .jpg or .png extension")\n\n        image = Image.open(image_path).convert(\'RGB\')\n        image = self.image_transforms(image)\n        pixel_values = self.feature_extractor(images=image, return_tensors="pt").pixel_values.squeeze()\n\n        text_inputs = self.tokenizer(text, return_tensors=\'pt\', padding=\'max_length\', truncation=True, max_length=128)\n\n        label = int(label)\n        assert 0 <= label < 2, f"Label {label} out of range"\n\n        return {\n            \'original_text\': text,\n            \'original_label\': label,\n            \'input_ids\': text_inputs[\'input_ids\'].squeeze(),\n            \'attention_mask\': text_inputs[\'attention_mask\'].squeeze(),\n            \'pixel_values\': pixel_values,\n            \'label\': torch.tensor(label, dtype=torch.long)\n        }\n'

# %%
# Create datasets
images_folder = '/kaggle/working/all Photos/'
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from transformers import BertTokenizer, ViTFeatureExtractor
from sklearn.metrics import accuracy_score

"""# Prepare dataset
tokenizer = BertTokenizer.from_pretrained('sagorsarker/bangla-bert-base')
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])

train_dataset = MultimodalDataset(train_data, images_folder, tokenizer, image_transforms, feature_extractor)
valid_dataset = MultimodalDataset(valid_data, images_folder, tokenizer, image_transforms, feature_extractor)
test_dataset = MultimodalDataset(test_data, images_folder, tokenizer, image_transforms, feature_extractor)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)"""
# Out:
# 2024-07-11 07:03:39.505793: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-11 07:03:39.505902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-11 07:03:39.652418: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# "# Prepare dataset\ntokenizer = BertTokenizer.from_pretrained('sagorsarker/bangla-bert-base')\nfeature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')\nimage_transforms = transforms.Compose([\n    transforms.Resize((224, 224)),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)\n])\n\ntrain_dataset = MultimodalDataset(train_data, images_folder, tokenizer, image_transforms, feature_extractor)\nvalid_dataset = MultimodalDataset(valid_data, images_folder, tokenizer, image_transforms, feature_extractor)\ntest_dataset = MultimodalDataset(test_data, images_folder, tokenizer, image_transforms, feature_extractor)\n\ntrain_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)\nvalid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=False)\ntest_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)"

# %%
"""print(len(train_dataset))
print(len(valid_dataset))
print(len(test_dataset))"""
# Out:
# 'print(len(train_dataset))\nprint(len(valid_dataset))\nprint(len(test_dataset))'

# %%
"""import os
import pandas as pd
import numpy as np
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torch
import matplotlib.pyplot as plt
from transformers import AutoTokenizer
import torchvision.transforms as transforms

# Assuming your dataset class is already defined as MultimodalDataset
# Ensure you have defined your dataframe, images_folder, tokenizer, and image_transforms

# Example DataFrame
data = {
    'Caption': ['বাংলা টেক্সট ১', 'বাংলা টেক্সট ২'],
    'Label': [0, 1],
    'Image id': ['image1', 'image2']
}
dataframe = df

# Path to the images folder
#images_folder = 'path/to/images'

# Initialize tokenizer and image transforms
tokenizer = AutoTokenizer.from_pretrained('bert-base-multilingual-cased')
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])
# Initialize dataset
dataset = MultimodalDataset(dataframe, images_folder, tokenizer, image_transforms)

# Create DataLoader
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

def imshow(image, ax=None, title=None, normalize=False):
    Imshow for Tensor.
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))
    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)
    ax.imshow(image)
    if title is not None:
        ax.set_title(title)
    ax.axis('off')
    return ax

def print_samples(dataloader, num_samples=5):
    count = 0
    for batch in dataloader:
        if count >= num_samples:
            break
        for i in range(len(batch['original_text'])):
            if count >= num_samples:
                break
            print(f"Sample {count+1}:")
            print(f"Original Text: {batch['original_text'][i]}")
            if batch['original_label'][i] == 1:
                #print(f"Original Label: {batch['original_label'][i]}")
                print("Original Label: Commercial")
            else:
                print("Original Label: Non commercial")
            #print(f"Input IDs: {batch['input_ids'][i]}")
            #print(f"Attention Mask: {batch['attention_mask'][i]}")
            #print(f"Image Tensor: {batch['image'][i].shape}")
            #print(f"Label: {batch['label'][i]}")

            # Plot the image
            imshow(batch['image'][i])
            plt.show()
            print()
            count += 1

# Print some samples from the dataset
print_samples(dataloader)"""
# Out:
# 'import os\nimport pandas as pd\nimport numpy as np\nfrom PIL import Image\nfrom torch.utils.data import Dataset, DataLoader\nimport torch\nimport matplotlib.pyplot as plt\nfrom transformers import AutoTokenizer\nimport torchvision.transforms as transforms\n\n# Assuming your dataset class is already defined as MultimodalDataset\n# Ensure you have defined your dataframe, images_folder, tokenizer, and image_transforms\n\n# Example DataFrame\ndata = {\n    \'Caption\': [\'বাংলা টেক্সট ১\', \'বাংলা টেক্সট ২\'],\n    \'Label\': [0, 1],\n    \'Image id\': [\'image1\', \'image2\']\n}\ndataframe = df\n\n# Path to the images folder\n#images_folder = \'path/to/images\'\n\n# Initialize tokenizer and image transforms\ntokenizer = AutoTokenizer.from_pretrained(\'bert-base-multilingual-cased\')\nimage_transforms = transforms.Compose([\n    transforms.Resize((224, 224)),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)\n])\n# Initialize dataset\ndataset = MultimodalDataset(dataframe, images_folder, tokenizer, image_transforms)\n\n# Create DataLoader\ndataloader = DataLoader(dataset, batch_size=2, shuffle=True)\n\ndef imshow(image, ax=None, title=None, normalize=False):\n    Imshow for Tensor.\n    if ax is None:\n        fig, ax = plt.subplots()\n    image = image.numpy().transpose((1, 2, 0))\n    if normalize:\n        mean = np.array([0.485, 0.456, 0.406])\n        std = np.array([0.229, 0.224, 0.225])\n        image = std * image + mean\n        image = np.clip(image, 0, 1)\n    ax.imshow(image)\n    if title is not None:\n        ax.set_title(title)\n    ax.axis(\'off\')\n    return ax\n\ndef print_samples(dataloader, num_samples=5):\n    count = 0\n    for batch in dataloader:\n        if count >= num_samples:\n            break\n        for i in range(len(batch[\'original_text\'])):\n            if count >= num_samples:\n                break\n            print(f"Sample {count+1}:")\n            print(f"Original Text: {batch[\'original_text\'][i]}")\n            if batch[\'original_label\'][i] == 1:\n                #print(f"Original Label: {batch[\'original_label\'][i]}")\n                print("Original Label: Commercial")\n            else:\n                print("Original Label: Non commercial")\n            #print(f"Input IDs: {batch[\'input_ids\'][i]}")\n            #print(f"Attention Mask: {batch[\'attention_mask\'][i]}")\n            #print(f"Image Tensor: {batch[\'image\'][i].shape}")\n            #print(f"Label: {batch[\'label\'][i]}")\n\n            # Plot the image\n            imshow(batch[\'image\'][i])\n            plt.show()\n            print()\n            count += 1\n\n# Print some samples from the dataset\nprint_samples(dataloader)'

# %%
#pip install transformers

# %%
"""import torch
import torch.nn as nn
from transformers import BertModel, ViTModel

class MultimodalModel(nn.Module):
    def __init__(self, text_model_name='sagorsarker/bangla-bert-base', image_model_name='google/vit-base-patch16-224', num_labels=2):
        super(MultimodalModel, self).__init__()
        self.text_model = BertModel.from_pretrained(text_model_name)
        self.image_model = ViTModel.from_pretrained(image_model_name)

        self.classifier = nn.Linear(self.text_model.config.hidden_size + self.image_model.config.hidden_size, num_labels)

    def forward(self, input_ids, attention_mask, pixel_values):
        # Text embeddings
        text_outputs = self.text_model(input_ids=input_ids, attention_mask=attention_mask)
        text_embeds = text_outputs.last_hidden_state[:, 0, :]  # Use [CLS] token embedding

        # Image embeddings
        image_outputs = self.image_model(pixel_values=pixel_values)
        image_embeds = image_outputs.last_hidden_state[:, 0, :]  # Use [CLS] token embedding from ViT

        # Combine embeddings
        combined_embeds = torch.cat((text_embeds, image_embeds), dim=1)
        logits = self.classifier(combined_embeds)

        return logits

# Example usage
# model = MultimodalModel(num_labels=len(df['Label'].unique()))"""
# Out:
# "import torch\nimport torch.nn as nn\nfrom transformers import BertModel, ViTModel\n\nclass MultimodalModel(nn.Module):\n    def __init__(self, text_model_name='sagorsarker/bangla-bert-base', image_model_name='google/vit-base-patch16-224', num_labels=2):\n        super(MultimodalModel, self).__init__()\n        self.text_model = BertModel.from_pretrained(text_model_name)\n        self.image_model = ViTModel.from_pretrained(image_model_name)\n\n        self.classifier = nn.Linear(self.text_model.config.hidden_size + self.image_model.config.hidden_size, num_labels)\n\n    def forward(self, input_ids, attention_mask, pixel_values):\n        # Text embeddings\n        text_outputs = self.text_model(input_ids=input_ids, attention_mask=attention_mask)\n        text_embeds = text_outputs.last_hidden_state[:, 0, :]  # Use [CLS] token embedding\n\n        # Image embeddings\n        image_outputs = self.image_model(pixel_values=pixel_values)\n        image_embeds = image_outputs.last_hidden_state[:, 0, :]  # Use [CLS] token embedding from ViT\n\n        # Combine embeddings\n        combined_embeds = torch.cat((text_embeds, image_embeds), dim=1)\n        logits = self.classifier(combined_embeds)\n\n        return logits\n\n# Example usage\n# model = MultimodalModel(num_labels=len(df['Label'].unique()))"

# %%
"""device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Instantiate model
model = MultimodalModel(num_labels=2)


# Define loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Training and validation loop
num_epochs = 10  # Set the number of epochs as required

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0
    total_train = 0
    
    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        pixel_values = batch['pixel_values'].to(device)
        labels = batch['label'].to(device)
        
        # Debugging statements
        print(f"Input IDs: {input_ids}")
        print(f"Attention Mask: {attention_mask}")
        print(f"Pixel Values: {pixel_values}")
        print(f"Labels: {labels}")

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask, pixel_values)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_accuracy = train_correct / total_train
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(train_loader)}, Train Accuracy: {train_accuracy}")
    
    model.eval()
    valid_loss = 0
    valid_correct = 0
    total_valid = 0
    
    with torch.no_grad():
        for batch in valid_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            pixel_values = batch['pixel_values'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask, pixel_values)
            loss = criterion(outputs, labels)
            
            valid_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_valid += labels.size(0)
            valid_correct += (predicted == labels).sum().item()

    valid_accuracy = valid_correct / total_valid
    print(f"Epoch {epoch+1}/{num_epochs}, Valid Loss: {valid_loss/len(valid_loader)}, Valid Accuracy: {valid_accuracy}")

# Save the model
torch.save(model.state_dict(), 'multimodal_model_vit.pth')"""
# Out:
# 'device = torch.device(\'cuda\' if torch.cuda.is_available() else \'cpu\')\n\n# Instantiate model\nmodel = MultimodalModel(num_labels=2)\n\n\n# Define loss and optimizer\ncriterion = nn.CrossEntropyLoss()\noptimizer = torch.optim.Adam(model.parameters(), lr=1e-4)\n\n# Training and validation loop\nnum_epochs = 10  # Set the number of epochs as required\n\nfor epoch in range(num_epochs):\n    model.train()\n    train_loss = 0\n    train_correct = 0\n    total_train = 0\n    \n    for batch in train_loader:\n        input_ids = batch[\'input_ids\'].to(device)\n        attention_mask = batch[\'attention_mask\'].to(device)\n        pixel_values = batch[\'pixel_values\'].to(device)\n        labels = batch[\'label\'].to(device)\n        \n        # Debugging statements\n        print(f"Input IDs: {input_ids}")\n        print(f"Attention Mask: {attention_mask}")\n        print(f"Pixel Values: {pixel_values}")\n        print(f"Labels: {labels}")\n\n        optimizer.zero_grad()\n        outputs = model(input_ids, attention_mask, pixel_values)\n        \n        loss = criterion(outputs, labels)\n        loss.backward()\n        optimizer.step()\n\n        train_loss += loss.item()\n        _, predicted = torch.max(outputs, 1)\n        total_train += labels.size(0)\n        train_correct += (predicted == labels).sum().item()\n\n    train_accuracy = train_correct / total_train\n    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(train_loader)}, Train Accuracy: {train_accuracy}")\n    \n    model.eval()\n    valid_loss = 0\n    valid_correct = 0\n    total_valid = 0\n    \n    with torch.no_grad():\n        for batch in valid_loader:\n            input_ids = batch[\'input_ids\'].to(device)\n            attention_mask = batch[\'attention_mask\'].to(device)\n            pixel_values = batch[\'pixel_values\'].to(device)\n            labels = batch[\'label\'].to(device)\n\n            outputs = model(input_ids, attention_mask, pixel_values)\n            loss = criterion(outputs, labels)\n            \n            valid_loss += loss.item()\n            _, predicted = torch.max(outputs, 1)\n            total_valid += labels.size(0)\n            valid_correct += (predicted == labels).sum().item()\n\n    valid_accuracy = valid_correct / total_valid\n    print(f"Epoch {epoch+1}/{num_epochs}, Valid Loss: {valid_loss/len(valid_loader)}, Valid Accuracy: {valid_accuracy}")\n\n# Save the model\ntorch.save(model.state_dict(), \'multimodal_model_vit.pth\')'

# %% [markdown]
# # With Custom Class

# %%
"""import torch
import torch.nn as nn
from torchvision import models

class CustomTransformerEncoder(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, max_length):
        super(CustomTransformerEncoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_length, d_model)
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, nhead),
            num_layers
        )

    def forward(self, input_ids, attention_mask):
        position_ids = torch.arange(0, input_ids.size(1), dtype=torch.long, device=input_ids.device)
        position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
        embedded = self.embedding(input_ids) + self.position_embedding(position_ids)
        mask = (attention_mask == 0)
        
        # Transpose mask to match the expected shape
        mask = mask.transpose(0, 1)
        
        encoded = self.transformer_encoder(embedded.transpose(0, 1), src_key_padding_mask=mask)
        return encoded.transpose(0, 1)


class CustomImageEncoder(nn.Module):
    def __init__(self, pretrained=True):
        super(CustomImageEncoder, self).__init__()
        resnet = models.resnet50(pretrained=pretrained)
        self.feature_extractor = nn.Sequential(*list(resnet.children())[:-1])  # Remove the last fully connected layer

    def forward(self, images):
        features = self.feature_extractor(images)
        features = features.view(features.size(0), -1)  # Flatten the tensor
        return features
"""
# Out:
# 'import torch\nimport torch.nn as nn\nfrom torchvision import models\n\nclass CustomTransformerEncoder(nn.Module):\n    def __init__(self, vocab_size, d_model, nhead, num_layers, max_length):\n        super(CustomTransformerEncoder, self).__init__()\n        self.embedding = nn.Embedding(vocab_size, d_model)\n        self.position_embedding = nn.Embedding(max_length, d_model)\n        self.transformer_encoder = nn.TransformerEncoder(\n            nn.TransformerEncoderLayer(d_model, nhead),\n            num_layers\n        )\n\n    def forward(self, input_ids, attention_mask):\n        position_ids = torch.arange(0, input_ids.size(1), dtype=torch.long, device=input_ids.device)\n        position_ids = position_ids.unsqueeze(0).expand_as(input_ids)\n        embedded = self.embedding(input_ids) + self.position_embedding(position_ids)\n        mask = (attention_mask == 0)\n        \n        # Transpose mask to match the expected shape\n        mask = mask.transpose(0, 1)\n        \n        encoded = self.transformer_encoder(embedded.transpose(0, 1), src_key_padding_mask=mask)\n        return encoded.transpose(0, 1)\n\n\nclass CustomImageEncoder(nn.Module):\n    def __init__(self, pretrained=True):\n        super(CustomImageEncoder, self).__init__()\n        resnet = models.resnet50(pretrained=pretrained)\n        self.feature_extractor = nn.Sequential(*list(resnet.children())[:-1])  # Remove the last fully connected layer\n\n    def forward(self, images):\n        features = self.feature_extractor(images)\n        features = features.view(features.size(0), -1)  # Flatten the tensor\n        return features\n'

# %%
"""class HierarchicalTextSplitMultimodalClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, max_length, num_layers, num_heads, num_classes=2):
        super(HierarchicalTextSplitMultimodalClassifier, self).__init__()
        # Custom text and image encoders
        self.text_encoder = CustomTransformerEncoder(vocab_size, embedding_dim, hidden_dim, max_length, num_layers, num_heads)
        self.image_encoder = CustomImageEncoder()
        
        # Self-attention layers for text features at different levels
        self.text_self_attention_low = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)
        self.text_self_attention_intermediate = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)
        self.text_self_attention_high = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)
        
        # Cross-attention layers for combining text and image features
        self.cross_attention_low = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)
        self.cross_attention_intermediate = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)
        self.cross_attention_high = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)
        
        # Fully connected layers for final classification
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim * 3 + 2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )
    
    def forward(self, text_input, attention_mask, image_input):
        # Extract low, intermediate, and high-level features from text encoder
        text_features_all = self.text_encoder(text_input, attention_mask)
        text_features_low = text_features_all[:, :128, :]
        text_features_intermediate = text_features_all[:, 128:256, :]
        text_features_high = text_features_all[:, 256:, :]
        
        # Apply self-attention to text features at each level
        text_features_low, _ = self.text_self_attention_low(text_features_low, text_features_low, text_features_low)
        text_features_intermediate, _ = self.text_self_attention_intermediate(text_features_intermediate, text_features_intermediate, text_features_intermediate)
        text_features_high, _ = self.text_self_attention_high(text_features_high, text_features_high, text_features_high)
        
        # Extract image features from image encoder
        image_features = self.image_encoder(image_input)
        
        # Apply cross-attention between text and image features at each level
        text_features_low, _ = self.cross_attention_low(text_features_low, image_features.unsqueeze(1), image_features.unsqueeze(1))
        text_features_intermediate, _ = self.cross_attention_intermediate(text_features_intermediate, image_features.unsqueeze(1), image_features.unsqueeze(1))
        text_features_high, _ = self.cross_attention_high(text_features_high, image_features.unsqueeze(1), image_features.unsqueeze(1))
        
        # Concatenate features from all levels
        combined_features = torch.cat((text_features_low.squeeze(1), text_features_intermediate.squeeze(1), text_features_high.squeeze(1), image_features), dim=1)
        
        # Pass through fully connected layers for classification
        logits = self.fc(combined_features)
        
        return logits"""
# Out:
# 'class HierarchicalTextSplitMultimodalClassifier(nn.Module):\n    def __init__(self, vocab_size, embedding_dim, hidden_dim, max_length, num_layers, num_heads, num_classes=2):\n        super(HierarchicalTextSplitMultimodalClassifier, self).__init__()\n        # Custom text and image encoders\n        self.text_encoder = CustomTransformerEncoder(vocab_size, embedding_dim, hidden_dim, max_length, num_layers, num_heads)\n        self.image_encoder = CustomImageEncoder()\n        \n        # Self-attention layers for text features at different levels\n        self.text_self_attention_low = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)\n        self.text_self_attention_intermediate = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)\n        self.text_self_attention_high = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)\n        \n        # Cross-attention layers for combining text and image features\n        self.cross_attention_low = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)\n        self.cross_attention_intermediate = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)\n        self.cross_attention_high = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=8)\n        \n        # Fully connected layers for final classification\n        self.fc = nn.Sequential(\n            nn.Linear(hidden_dim * 3 + 2048, 512),\n            nn.ReLU(),\n            nn.Dropout(0.5),\n            nn.Linear(512, num_classes)\n        )\n    \n    def forward(self, text_input, attention_mask, image_input):\n        # Extract low, intermediate, and high-level features from text encoder\n        text_features_all = self.text_encoder(text_input, attention_mask)\n        text_features_low = text_features_all[:, :128, :]\n        text_features_intermediate = text_features_all[:, 128:256, :]\n        text_features_high = text_features_all[:, 256:, :]\n        \n        # Apply self-attention to text features at each level\n        text_features_low, _ = self.text_self_attention_low(text_features_low, text_features_low, text_features_low)\n        text_features_intermediate, _ = self.text_self_attention_intermediate(text_features_intermediate, text_features_intermediate, text_features_intermediate)\n        text_features_high, _ = self.text_self_attention_high(text_features_high, text_features_high, text_features_high)\n        \n        # Extract image features from image encoder\n        image_features = self.image_encoder(image_input)\n        \n        # Apply cross-attention between text and image features at each level\n        text_features_low, _ = self.cross_attention_low(text_features_low, image_features.unsqueeze(1), image_features.unsqueeze(1))\n        text_features_intermediate, _ = self.cross_attention_intermediate(text_features_intermediate, image_features.unsqueeze(1), image_features.unsqueeze(1))\n        text_features_high, _ = self.cross_attention_high(text_features_high, image_features.unsqueeze(1), image_features.unsqueeze(1))\n        \n        # Concatenate features from all levels\n        combined_features = torch.cat((text_features_low.squeeze(1), text_features_intermediate.squeeze(1), text_features_high.squeeze(1), image_features), dim=1)\n        \n        # Pass through fully connected layers for classification\n        logits = self.fc(combined_features)\n        \n        return logits'

# %%
"""import os
from torch.utils.data import Dataset
from PIL import Image
import torch
from transformers import BertTokenizer
from torchvision import transforms

class MultimodalDataset(Dataset):
    def __init__(self, dataframe, images_folder, tokenizer, image_transforms):
        self.dataframe = dataframe
        self.images_folder = images_folder
        self.tokenizer = tokenizer
        self.image_transforms = image_transforms

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        text = row['Caption']
        label = row['Label']
        image_id = row['Image id']

        image_path_jpg = os.path.join(self.images_folder, f"{image_id}.jpg")
        image_path_png = os.path.join(self.images_folder, f"{image_id}.png")

        if os.path.exists(image_path_jpg):
            image_path = image_path_jpg
        elif os.path.exists(image_path_png):
            image_path = image_path_png
        else:
            raise FileNotFoundError(f"Image {image_id} not found with .jpg or .png extension")

        image = Image.open(image_path).convert('RGB')
        image = self.image_transforms(image)

        text_inputs = self.tokenizer(text, return_tensors='pt', padding='max_length', truncation=True, max_length=128)

        label = int(label)
        assert 0 <= label < 2, f"Label {label} out of range"

        return {
            'original_text': text,
            'original_label': label,
            'input_ids': text_inputs['input_ids'].squeeze(),
            'attention_mask': text_inputs['attention_mask'].squeeze(),
            'pixel_values': image,
            'label': torch.tensor(label, dtype=torch.long)
        }

# Define image transformations
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Instantiate tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

images_folder = '/kaggle/working/all Photos/'
# Create dataset and dataloader
train_dataset = MultimodalDataset(train_data, images_folder, tokenizer, image_transforms)
valid_dataset = MultimodalDataset(valid_data, images_folder, tokenizer, image_transforms)
test_dataset = MultimodalDataset(test_data, images_folder, tokenizer, image_transforms)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)"""
# Out:
# 'import os\nfrom torch.utils.data import Dataset\nfrom PIL import Image\nimport torch\nfrom transformers import BertTokenizer\nfrom torchvision import transforms\n\nclass MultimodalDataset(Dataset):\n    def __init__(self, dataframe, images_folder, tokenizer, image_transforms):\n        self.dataframe = dataframe\n        self.images_folder = images_folder\n        self.tokenizer = tokenizer\n        self.image_transforms = image_transforms\n\n    def __len__(self):\n        return len(self.dataframe)\n\n    def __getitem__(self, idx):\n        row = self.dataframe.iloc[idx]\n        text = row[\'Caption\']\n        label = row[\'Label\']\n        image_id = row[\'Image id\']\n\n        image_path_jpg = os.path.join(self.images_folder, f"{image_id}.jpg")\n        image_path_png = os.path.join(self.images_folder, f"{image_id}.png")\n\n        if os.path.exists(image_path_jpg):\n            image_path = image_path_jpg\n        elif os.path.exists(image_path_png):\n            image_path = image_path_png\n        else:\n            raise FileNotFoundError(f"Image {image_id} not found with .jpg or .png extension")\n\n        image = Image.open(image_path).convert(\'RGB\')\n        image = self.image_transforms(image)\n\n        text_inputs = self.tokenizer(text, return_tensors=\'pt\', padding=\'max_length\', truncation=True, max_length=128)\n\n        label = int(label)\n        assert 0 <= label < 2, f"Label {label} out of range"\n\n        return {\n            \'original_text\': text,\n            \'original_label\': label,\n            \'input_ids\': text_inputs[\'input_ids\'].squeeze(),\n            \'attention_mask\': text_inputs[\'attention_mask\'].squeeze(),\n            \'pixel_values\': image,\n            \'label\': torch.tensor(label, dtype=torch.long)\n        }\n\n# Define image transformations\nimage_transforms = transforms.Compose([\n    transforms.Resize((224, 224)),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),\n])\n\n# Instantiate tokenizer\ntokenizer = BertTokenizer.from_pretrained(\'bert-base-uncased\')\n\nimages_folder = \'/kaggle/working/all Photos/\'\n# Create dataset and dataloader\ntrain_dataset = MultimodalDataset(train_data, images_folder, tokenizer, image_transforms)\nvalid_dataset = MultimodalDataset(valid_data, images_folder, tokenizer, image_transforms)\ntest_dataset = MultimodalDataset(test_data, images_folder, tokenizer, image_transforms)\n\ntrain_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)\nvalid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)\ntest_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)'

# %%
"""import torch
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define model parameters
vocab_size = tokenizer.vocab_size
d_model = 512
nhead = 8
num_layers = 6
max_length = 128
num_classes = 2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = HierarchicalTextSplitMultimodalClassifier(vocab_size, d_model, nhead, num_layers, max_length, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 5

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0
    total_train = 0

    for batch in train_loader:
        text_input = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        image_input = batch['pixel_values'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(text_input, attention_mask, image_input)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        train_correct += (predicted == labels).sum().item()
        total_train += labels.size(0)

    train_accuracy = train_correct / total_train

    model.eval()
    valid_loss = 0
    valid_correct = 0
    total_valid = 0

    with torch.no_grad():
        for batch in valid_loader:
            text_input = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            image_input = batch['pixel_values'].to(device)
            labels = batch['label'].to(device)

            outputs = model(text_input, attention_mask, image_input)
            loss = criterion(outputs, labels)

            valid_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            valid_correct += (predicted == labels).sum().item()
            total_valid += labels.size(0)

    valid_accuracy = valid_correct / total_valid

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(train_loader)}, Train Accuracy: {train_accuracy}, Valid Loss: {valid_loss/len(valid_loader)}, Valid Accuracy: {valid_accuracy}")

# Testing loop
#model.eval()
# Save the model
torch.save(model.state_dict(), 'hierarchical_multimodal_model.pth')"""
# Out:
# 'import torch\nfrom torch.utils.data import DataLoader\nfrom sklearn.metrics import accuracy_score\n\ndevice = torch.device(\'cuda\' if torch.cuda.is_available() else \'cpu\')\n\n# Define model parameters\nvocab_size = tokenizer.vocab_size\nd_model = 512\nnhead = 8\nnum_layers = 6\nmax_length = 128\nnum_classes = 2\n\ndevice = torch.device(\'cuda\' if torch.cuda.is_available() else \'cpu\')\n\nmodel = HierarchicalTextSplitMultimodalClassifier(vocab_size, d_model, nhead, num_layers, max_length, num_classes).to(device)\n\ncriterion = nn.CrossEntropyLoss()\noptimizer = optim.Adam(model.parameters(), lr=0.001)\n\n# Training loop\nnum_epochs = 5\n\nfor epoch in range(num_epochs):\n    model.train()\n    train_loss = 0\n    train_correct = 0\n    total_train = 0\n\n    for batch in train_loader:\n        text_input = batch[\'input_ids\'].to(device)\n        attention_mask = batch[\'attention_mask\'].to(device)\n        image_input = batch[\'pixel_values\'].to(device)\n        labels = batch[\'label\'].to(device)\n\n        optimizer.zero_grad()\n        outputs = model(text_input, attention_mask, image_input)\n        loss = criterion(outputs, labels)\n        loss.backward()\n        optimizer.step()\n\n        train_loss += loss.item()\n        _, predicted = torch.max(outputs, 1)\n        train_correct += (predicted == labels).sum().item()\n        total_train += labels.size(0)\n\n    train_accuracy = train_correct / total_train\n\n    model.eval()\n    valid_loss = 0\n    valid_correct = 0\n    total_valid = 0\n\n    with torch.no_grad():\n        for batch in valid_loader:\n            text_input = batch[\'input_ids\'].to(device)\n            attention_mask = batch[\'attention_mask\'].to(device)\n            image_input = batch[\'pixel_values\'].to(device)\n            labels = batch[\'label\'].to(device)\n\n            outputs = model(text_input, attention_mask, image_input)\n            loss = criterion(outputs, labels)\n\n            valid_loss += loss.item()\n            _, predicted = torch.max(outputs, 1)\n            valid_correct += (predicted == labels).sum().item()\n            total_valid += labels.size(0)\n\n    valid_accuracy = valid_correct / total_valid\n\n    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(train_loader)}, Train Accuracy: {train_accuracy}, Valid Loss: {valid_loss/len(valid_loader)}, Valid Accuracy: {valid_accuracy}")\n\n# Testing loop\n#model.eval()\n# Save the model\ntorch.save(model.state_dict(), \'hierarchical_multimodal_model.pth\')'

# %%
# Prediction loop
"""model.eval()
all_labels = []
all_preds = []

with torch.no_grad():
    for batch in test_loader:
        text_input = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        image_input = batch['pixel_values'].to(device)
        labels = batch['label'].to(device)

        outputs = model(text_input, attention_mask, image_input)
        _, predicted = torch.max(outputs, 1)
        
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

# Calculate test accuracy
test_accuracy = accuracy_score(all_labels, all_preds)
print(f"Test Accuracy: {test_accuracy}")"""
# Out:
# 'model.eval()\nall_labels = []\nall_preds = []\n\nwith torch.no_grad():\n    for batch in test_loader:\n        text_input = batch[\'input_ids\'].to(device)\n        attention_mask = batch[\'attention_mask\'].to(device)\n        image_input = batch[\'pixel_values\'].to(device)\n        labels = batch[\'label\'].to(device)\n\n        outputs = model(text_input, attention_mask, image_input)\n        _, predicted = torch.max(outputs, 1)\n        \n        all_labels.extend(labels.cpu().numpy())\n        all_preds.extend(predicted.cpu().numpy())\n\n# Calculate test accuracy\ntest_accuracy = accuracy_score(all_labels, all_preds)\nprint(f"Test Accuracy: {test_accuracy}")'

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
from torchvision import transforms
from PIL import Image
import pandas as pd

class MultimodalDataset(Dataset):
    def __init__(self, dataframe, images_folder, tokenizer, image_transforms):
        self.dataframe = dataframe
        self.images_folder = images_folder
        self.tokenizer = tokenizer
        self.image_transforms = image_transforms

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        text = row['Caption']
        label = row['Label']
        image_id = row['Image id']

        image_path_jpg = os.path.join(self.images_folder, f"{image_id}.jpg")
        image_path_png = os.path.join(self.images_folder, f"{image_id}.png")

        if os.path.exists(image_path_jpg):
            image_path = image_path_jpg
        elif os.path.exists(image_path_png):
            image_path = image_path_png
        else:
            raise FileNotFoundError(f"Image {image_id} not found with .jpg or .png extension")

        image = Image.open(image_path).convert('RGB')
        image = self.image_transforms(image)

        text_inputs = self.tokenizer(text, return_tensors='pt', padding='max_length', truncation=True, max_length=128)

        label = int(label)
        assert 0 <= label < 2, f"Label {label} out of range"

        return {
            'original_text': text,
            'original_label': label,
            'input_ids': text_inputs['input_ids'].squeeze(),
            'attention_mask': text_inputs['attention_mask'].squeeze(),
            'pixel_values': image,
            'label': torch.tensor(label, dtype=torch.long)
        }

"""class CustomTransformerEncoder(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, max_length):
        super(CustomTransformerEncoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_length, d_model)
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, nhead),
            num_layers
        )

    def forward(self, input_ids, attention_mask):
        position_ids = torch.arange(0, input_ids.size(1), dtype=torch.long, device=input_ids.device)
        position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
        embedded = self.embedding(input_ids) + self.position_embedding(position_ids)
        
        # The attention mask needs to have shape (batch_size, seq_length) for key_padding_mask
        mask = attention_mask == 0  # Convert to boolean mask where padding tokens are marked as True
        
        encoded = self.transformer_encoder(embedded.transpose(0, 1), src_key_padding_mask=mask)
        return encoded.transpose(0, 1)

class HierarchicalTextSplitMultimodalClassifier(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, max_length, num_classes):
        super(HierarchicalTextSplitMultimodalClassifier, self).__init__()
        self.text_encoder = CustomTransformerEncoder(vocab_size, d_model, nhead, num_layers, max_length)
        self.image_encoder = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(32 * 56 * 56, 512),
            nn.ReLU()
        )
        self.fc = nn.Linear(512 + d_model, num_classes)

    def forward(self, text_input, attention_mask, image_input):
        text_features_all = self.text_encoder(text_input, attention_mask)
        
        seq_len = text_features_all.size(1)
        text_features_low = text_features_all[:, :seq_len // 3, :]
        text_features_intermediate = text_features_all[:, seq_len // 3:2 * seq_len // 3, :]
        text_features_high = text_features_all[:, 2 * seq_len // 3:, :]

        image_features = self.image_encoder(image_input)

        combined_features = torch.cat((image_features, text_features_high[:, 0, :]), dim=1)
        logits = self.fc(combined_features)
        return logits"""

import torch
import torch.nn as nn
from transformers import ViTModel, ViTFeatureExtractor, BertTokenizer

class CustomTransformerEncoder(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, max_length):
        super(CustomTransformerEncoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_length, d_model)
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, nhead),
            num_layers
        )

    def forward(self, input_ids, attention_mask):
        position_ids = torch.arange(0, input_ids.size(1), dtype=torch.long, device=input_ids.device)
        position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
        embedded = self.embedding(input_ids) + self.position_embedding(position_ids)
        
        mask = attention_mask == 0  # Convert to boolean mask where padding tokens are marked as True
        
        encoded = self.transformer_encoder(embedded.transpose(0, 1), src_key_padding_mask=mask)
        return encoded.transpose(0, 1)

class HierarchicalTextSplitMultimodalClassifier(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, max_length, num_classes):
        super(HierarchicalTextSplitMultimodalClassifier, self).__init__()
        self.text_encoder = CustomTransformerEncoder(vocab_size, d_model, nhead, num_layers, max_length)
        
        self.vit_model = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
        self.vit_feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')

        self.fc = nn.Linear(self.vit_model.config.hidden_size + d_model, num_classes)

    def forward(self, text_input, attention_mask, image_input):
        text_features_all = self.text_encoder(text_input, attention_mask)
        
        seq_len = text_features_all.size(1)
        text_features_low = text_features_all[:, :seq_len // 3, :]
        text_features_intermediate = text_features_all[:, seq_len // 3:2 * seq_len // 3, :]
        text_features_high = text_features_all[:, 2 * seq_len // 3:, :]

        # Ensure image_input is in the correct shape and range
        image_input = image_input.permute(0, 2, 3, 1)  # Change to (batch_size, height, width, channels)
        image_input = image_input.cpu().numpy()  # Move to CPU and convert to NumPy array
        image_input = (image_input * 255).astype(np.uint8)  # Scale to [0, 255] and convert to uint8
        
        image_features = self.vit_feature_extractor(images=image_input, return_tensors='pt').pixel_values
        image_features = image_features.to(text_input.device)  # Move to the same device as text_input
        image_features = self.vit_model(image_features).last_hidden_state[:, 0, :]  # Use the [CLS] token representation

        combined_features = torch.cat((image_features, text_features_high[:, 0, :]), dim=1)
        logits = self.fc(combined_features)
        return logits



# Define image transformations
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Instantiate tokenizer
from transformers import XLMRobertaTokenizer
#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base')
#tokenizer = BertTokenizer.from_pretrained('sagorsarker/bangla-bert-base')
#tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')

import numpy as np
images_folder = '/kaggle/working/all Photos/'
# Assuming `train_dataframe`, `valid_dataframe`, `test_dataframe` are predefined
train_dataset = MultimodalDataset(train_data, images_folder, tokenizer, image_transforms)
valid_dataset = MultimodalDataset(valid_data, images_folder, tokenizer, image_transforms)
test_dataset = MultimodalDataset(test_data, images_folder, tokenizer, image_transforms)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define model parameters
vocab_size = tokenizer.vocab_size
d_model = 512
nhead = 8
num_layers = 6
max_length = 128
num_classes = 2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = HierarchicalTextSplitMultimodalClassifier(vocab_size, d_model, nhead, num_layers, max_length, num_classes).to(device)

print('criterion er upore')
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=2e-4)

# Training loop
num_epochs = 10
print('train epoch e dhukse')
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0
    total_train = 0
    print('epoch : ', epoch)
    for batch in train_loader:
        text_input = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        image_input = batch['pixel_values'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(text_input, attention_mask, image_input)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        train_correct += (predicted == labels).sum().item()
        total_train += labels.size(0)

    train_accuracy = train_correct / total_train
    print('train_acc : ', train_accuracy)

    model.eval()
    valid_loss = 0
    valid_correct = 0
    total_valid = 0

    with torch.no_grad():
        print('valid e dhukse')
        for batch in valid_loader:
            text_input = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            image_input = batch['pixel_values'].to(device)
            labels = batch['label'].to(device)

            outputs = model(text_input, attention_mask, image_input)
            loss = criterion(outputs, labels)

            valid_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            valid_correct += (predicted == labels).sum().item()
            total_valid += labels.size(0)

    valid_accuracy = valid_correct / total_valid

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss/len(train_loader)}, Train Accuracy: {train_accuracy}, Valid Loss: {valid_loss/len(valid_loader)}, Valid Accuracy: {valid_accuracy}")

# Testing loop
"""model.eval()
test_correct = 0
total_test = 0

with torch.no_grad():
    for batch in test_loader:
        text_input = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        image_input = batch['pixel_values'].to(device)
        labels = batch['label'].to(device)

        outputs = model(text_input, attention_mask, image_input)
        _, predicted = torch.max(outputs, 1)
        test_correct += (predicted == labels).sum().item()
        total_test += labels.size(0)

test_accuracy = test_correct / total_test
print(f"Test Accuracy: {test_accuracy}")"""
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# criterion er upore
# train epoch e dhukse
# epoch :  0
# train_acc :  0.7292707292707292
# valid e dhukse
# Epoch 1/10, Train Loss: 0.536043292347421, Train Accuracy: 0.7292707292707292, Valid Loss: 0.438467085827142, Valid Accuracy: 0.8121878121878122
# epoch :  1
# train_acc :  0.9004329004329005
# valid e dhukse
# Epoch 2/10, Train Loss: 0.25665651420329477, Train Accuracy: 0.9004329004329005, Valid Loss: 0.3587742103263736, Valid Accuracy: 0.8731268731268731
# epoch :  2
# train_acc :  0.9500499500499501
# valid e dhukse
# Epoch 3/10, Train Loss: 0.125007518151022, Train Accuracy: 0.9500499500499501, Valid Loss: 0.3196288044564426, Valid Accuracy: 0.8621378621378621
# epoch :  3
# train_acc :  0.9726939726939727
# valid e dhukse
# Epoch 4/10, Train Loss: 0.0728679731354474, Train Accuracy: 0.9726939726939727, Valid Loss: 0.34753484395332634, Valid Accuracy: 0.8901098901098901
# epoch :  4
# train_acc :  0.9723609723609724
# valid e dhukse
# Epoch 5/10, Train Loss: 0.07226009524001324, Train Accuracy: 0.9723609723609724, Valid Loss: 0.3965083286166191, Valid Accuracy: 0.8801198801198801
# epoch :  5
# train_acc :  0.9903429903429903
# valid e dhukse
# Epoch 6/10, Train Loss: 0.03086590972367397, Train Accuracy: 0.9903429903429903, Valid Loss: 0.3887742354418151, Valid Accuracy: 0.8941058941058941
# epoch :  6
# train_acc :  0.9936729936729937
# valid e dhukse
# Epoch 7/10, Train Loss: 0.02165540584060859, Train Accuracy: 0.9936729936729937, Valid Loss: 0.33294571784790605, Valid Accuracy: 0.9050949050949051
# epoch :  7
# train_acc :  0.9986679986679987
# valid e dhukse
# Epoch 8/10, Train Loss: 0.006760100345963246, Train Accuracy: 0.9986679986679987, Valid Loss: 0.32876538202981465, Valid Accuracy: 0.9240759240759241
# epoch :  8
# train_acc :  0.9996669996669997
# valid e dhukse
# Epoch 9/10, Train Loss: 0.002379707700728954, Train Accuracy: 0.9996669996669997, Valid Loss: 0.3314480720437132, Valid Accuracy: 0.9180819180819181
# epoch :  9
# train_acc :  0.9993339993339994
# valid e dhukse
# Epoch 10/10, Train Loss: 0.0020203170346615074, Train Accuracy: 0.9993339993339994, Valid Loss: 0.3465272029861808, Valid Accuracy: 0.9170829170829171
# 'model.eval()\ntest_correct = 0\ntotal_test = 0\n\nwith torch.no_grad():\n    for batch in test_loader:\n        text_input = batch[\'input_ids\'].to(device)\n        attention_mask = batch[\'attention_mask\'].to(device)\n        image_input = batch[\'pixel_values\'].to(device)\n        labels = batch[\'label\'].to(device)\n\n        outputs = model(text_input, attention_mask, image_input)\n        _, predicted = torch.max(outputs, 1)\n        test_correct += (predicted == labels).sum().item()\n        total_test += labels.size(0)\n\ntest_accuracy = test_correct / total_test\nprint(f"Test Accuracy: {test_accuracy}")'

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

def evaluate_model(model, test_loader):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['pixel_values'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask, images)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_labels = ['Commercial' if label == 1 else 'Non commercial' for label in all_labels]
    all_preds = ['Commercial' if pred == 1 else 'Non commercial' for pred in all_preds]
    
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')
    report = classification_report(all_labels, all_preds, target_names=['Non commercial', 'Commercial'])

    return accuracy, precision, recall, f1, report, all_labels, all_preds

# Example usage:
accuracy, precision, recall, f1, report, all_labels, all_preds = evaluate_model(model, test_loader)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.9182
# Precision: 0.9181
# Recall: 0.9182
# F1 Score: 0.9180
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Non commercial       0.92      0.94      0.93       573
#     Commercial       0.92      0.89      0.90       429
#
#       accuracy                           0.92      1002
#      macro avg       0.92      0.91      0.92      1002
#   weighted avg       0.92      0.92      0.92      1002

# %%
def plot_confusion_matrix(all_labels, all_preds):
    labels = ['Commercial', 'Non commercial']
    cm = confusion_matrix(all_labels, all_preds, labels=labels)
    plt.figure(figsize=(8, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.savefig('/kaggle/working/xlmr+ViT_confusion_matrix.png')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plot_confusion_matrix(all_labels, all_preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 plot_confusion_matrix(all_labels, all_preds)
#
# Cell In[22], line 3, in plot_confusion_matrix(all_labels, all_preds)
#       1 def plot_confusion_matrix(all_labels, all_preds):
#       2     labels = ['Commercial', 'Non commercial']
# ----> 3     cm = confusion_matrix(all_labels, all_preds, labels=labels)
#       4     plt.figure(figsize=(8, 5))
#       5     sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
#
# NameError: name 'confusion_matrix' is not defined
